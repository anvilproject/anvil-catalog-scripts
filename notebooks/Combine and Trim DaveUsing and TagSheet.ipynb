# %%
from datetime import datetime
import firecloud.api as FAPI
import json
import os
import pandas as pd
import pprint

print(FAPI.whoami())
pp = pprint.PrettyPrinter(indent=4)

BILLING_PROJECT_ID = os.environ['WORKSPACE_NAMESPACE']
WORKSPACE = os.environ['WORKSPACE_NAME']
WORKSPACE_BUCKET = os.environ['WORKSPACE_BUCKET']
CATALOG_WORKSPACE_NAMESPACE = "anvil-datastorage"


# !gsutil cp $WORKSPACE_BUCKET/AnVIL_Data_Ingestion_Attributes_210225-November-2-2021-1_17-PM-Dave_Using.csv  .
# !gsutil cp $WORKSPACE_BUCKET/attributes_for_AnVIL_workspaces_update_210217.csv  .


## Read in Dave Using list
daveUsing = pd.read_csv('AnVIL_Data_Ingestion_Attributes_210225-November-2-2021-1_17-PM-Dave_Using.csv',keep_default_na=False)
daveUsing = daveUsing[["name","library:dataUseRestriction", "library:datatype.items", "library:indication", "study_accession", "library:studyDesign","x"]]
daveUsing.set_index("name", inplace=True)

## Read in Tags Sheet 02-17
tagSheet = pd.read_csv('attributes_for_AnVIL_workspaces_update_210217.csv',keep_default_na=False)
tagSheet = tagSheet[["name","library:dataUseRestriction", "library:datatype.items", "library:indication", "library:studyDesign", "tag:tags.items"]]
tagSheet.set_index("name", inplace=True)
# Out:
# pet-117272931645288568532@terra-e36fcccd.iam.gserviceaccount.com
# Copying gs://fc-cb5be780-171f-49d4-9116-b77fd2237d0b/AnVIL_Data_Ingestion_Attributes_210225-November-2-2021-1_17-PM-Dave_Using.csv...
# / [1 files][287.8 KiB/287.8 KiB]
# Operation completed over 1 objects/287.8 KiB.
# Copying gs://fc-cb5be780-171f-49d4-9116-b77fd2237d0b/attributes_for_AnVIL_workspaces_update_210217.csv...
# / [1 files][293.9 KiB/293.9 KiB]
# Operation completed over 1 objects/293.9 KiB.

# %%
"""
Extract only the fields we want from each file.
Write a single file that if dave using exists takes that data 
and if dave using does not exist takes the tag sheet data
Tag sheet data file is bigger so we will interate over that first.
"""

def extractTagSheetTagItem(workspaceName, tagName):
    if workspaceName in tagSheet.index:
        items = tagSheet.at[workspaceName,"tag:tags.items"]
        items = cleanUpDbGapTagSheetTag(items)
        items = items.split(",")
        for item in items:
            item = item.strip()
            if item.startswith(tagName):
                parts = item.split(":")
                if len(parts) == 2:
                    return parts[1]
                else:
                    return ""
        ## Not found reuturn unspecified
        return ""
    return ""
    

def cleanUpDbGapTagSheetTag(tag):
    if pd.isna(tag):
            return ""
            
    tag = tag.replace("'","")
    tag = tag.replace("[","")
    tag = tag.replace("]","")
    return tag


def setUnspecified(value):
    if pd.isna(value) or value == "":
        return "TBD"
    else:
        return value

def cleanUpDbGaPId(dbGaPId):
    if (dbGaPId == "--"):
        return 'None'
    elif dbGaPId == "registration pending":
        return "Registration Pending"
    elif dbGaPId == 'available through EGA':
        return "Available through EGA"
    else:
        return dbGaPId   

def cleanStudyDesign(studyDesign):
    if studyDesign == "Case/Control":
        return 'Case-Control'
    if studyDesign == "Case-Control":
        return 'Case-Control'
    elif studyDesign == "Control":
        return "Control Set"
    elif studyDesign == 'Controls':
        return "Control Set"
    elif studyDesign == 'Cross-sectional':
        return "Cross-Sectional"
    elif  studyDesign == "NA" or studyDesign == "N/A":
        return "TBD"
    else:
        return studyDesign  
    
def cleanUpStudyDesigns(studyDesigns):
    studyDesigns = studyDesigns.split(',')
    clean = []
    for sd in studyDesigns:
        clean.append(cleanStudyDesign(sd))
    return ','.join(clean)

def cleanDatatype(studyDesign):
    if studyDesign == "AttributeValue" or studyDesign == "NA" or studyDesign == "N/A":
        return "TBD"
    else:
        return studyDesign  
    
def cleanUpDatatypes(dataTypes):
    dataTypes = dataTypes.split(',')
    clean = []
    for sd in dataTypes:
        clean.append(cleanDatatype(sd))
    return ','.join(clean)

def cleanUpDataUseRestrictions(r):
    if r == "open access":
        return "NRES"
    if r == "NA" or r == "N/A":
            return "TBD"
    if r == "not applicable":
            return "Consortia Access Only"
    else:
        return r
    
def cleanUpIndication(ind):
    if ind == "not applicable":
        return "None"
    else:
        return ind



catalogArray = []

for name in tagSheet.index:
    if name in daveUsing.index:
        wsAttributes = {
                'name': name,
                'consortium': daveUsing.at[name,"x"],
                'phsId': daveUsing.at[name,"study_accession"],
                'library:indication': daveUsing.at[name,"library:indication"],
                'library:studyDesign': daveUsing.at[name,"library:studyDesign"],
                'library:datatype': daveUsing.at[name,"library:datatype.items"],
                'library:dataUseRestriction': daveUsing.at[name,"library:dataUseRestriction"],
            }
    else:
         wsAttributes = {
                'name': name,
                'consortium': extractTagSheetTagItem(name,"consortium"),
                'phsId': extractTagSheetTagItem(name,"dbGaP"),
                'library:indication':tagSheet.at[name,"library:indication"],
                'library:studyDesign': tagSheet.at[name,"library:studyDesign"],
                'library:datatype': cleanUpDbGapTagSheetTag(tagSheet.at[name,"library:datatype.items"]),
                'library:dataUseRestriction':  tagSheet.at[name,"library:dataUseRestriction"],
            }
       
    wsAttributes['consortium'] = setUnspecified(wsAttributes['consortium'])
    wsAttributes['phsId'] = setUnspecified(cleanUpDbGaPId(wsAttributes['phsId'])) 
    wsAttributes["library:indication"] = setUnspecified(cleanUpIndication(wsAttributes["library:indication"]))
    wsAttributes['library:studyDesign'] = setUnspecified(cleanUpStudyDesigns(wsAttributes['library:studyDesign']))  
    wsAttributes["library:datatype"] = setUnspecified(cleanUpDatatypes(wsAttributes["library:datatype"]))
    wsAttributes["library:dataUseRestriction"] = cleanUpDataUseRestrictions(wsAttributes["library:dataUseRestriction"]) 
       
                                            
 
    catalogArray.append(wsAttributes)

    

    
fileName = 'AnVILCatalogWorkspacesInput-'+datetime.today().strftime('%Y-%m-%d')+".csv"

catalogDF = pd.DataFrame(catalogArray)
catalogDF.set_index("name", inplace=True)
catalogDF.to_csv(fileName)
# !gsutil cp ./$fileName $WORKSPACE_BUCKET/

pp.pprint(catalogArray)
# Out:
# Copying file://./AnVILCatalogWorkspacesInput-2022-03-08.csv [Content-Type=text/csv]...
# / [1 files][ 50.2 KiB/ 50.2 KiB]
# Operation completed over 1 objects/50.2 KiB.
# [   {   'consortium': '1000G',
#         'library:dataUseRestriction': 'NRES',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'None',
#         'library:studyDesign': 'Parent-Offspring Trios',
#         'name': '1000G-high-coverage-2019',
#         'phsId': 'None'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-CVD',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'heart and blood vessel disease',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_WashU_CVD_EOCAD_BioImage_WGS',
#         'phsId': 'phs002325'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-ASD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_chung_asd_exome',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-ASD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_ac-boston_asd_exome',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_lattig_asd_exome',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_puura_asd_exome',
#         'phsId': 'Available through EGA'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_kolevzon_asd_wgs',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Case-Control',
#         'name': 'anvil_ccdg_asc_ndd_daly_talkowski_schloesser_asd_gsa-md',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Case-Control',
#         'name': 'anvil_ccdg_asc_ndd_daly_talkowski_gurrieri_asd_exome',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-ASD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_menashe_asd_exome',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-ASD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_AGRE_asd_exome',
#         'phsId': 'phs001766'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-ASD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_domenici_asd_exome',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-ASD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_TASC_asd_exome',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-ASD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_passos-bueno_asd_exome',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-ASD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_AGRE-FEMF_asd_exome',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_control_NIMH_asd_exome',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-MH',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_renieri_asd_exome',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Autism_State-Sanders_WGS',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_barbosa_asd_exome',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-ASD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_herman_asd_exome',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-ASD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_palotie_asd_exome',
#         'phsId': 'Available through EGA'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_kolevzon_asd_exome',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_CDCSEED_asd_exome',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-ASD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_hertz-picciotto_asd_exome',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_pericak-vance_asd_exome_',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-ASD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_weiss_asd_exome',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'HMB',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_pericak-vance_asd_wgs',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-ASD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_goethe_asd_exome',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-ND',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_mcpartland_asd_exome',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-ASD',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_hertz-picciotto_asd_wgs',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU-NPU',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_persico_asd_exome',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_brusco_asd_exome',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-ASD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_parellada_asd_exome',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_IBIS_asd_exome',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_mayo_asd_exome',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-ASD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_minshew_asd_exome',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'Case-Control',
#         'name': 'anvil_ccdg_asc_ndd_daly_talkowski_cdcseed_asd_gsa-md',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'autism spectrum disorder',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_ccdg_asc_ndd_daly_talkowski_schloesser_asd_exome',
#         'phsId': 'phs000298'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'HMB-NPU',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'Unspecified',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_WashU_CVD_PAGE_HMB-NPU_WGS',
#         'phsId': 'phs000356'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Whole Genome',
#         'library:indication': "Alzheimer's disease",
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_NYGC_NP_Alz_EFIGA_WGS',
#         'phsId': 'phs000496'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Whole Genome',
#         'library:indication': "Alzheimer's disease",
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_NYGC_NP_Alz_WHICAP_WGS',
#         'phsId': 'phs000496'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-LD-RD',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'asthma',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_NYGC_AI_Asthma_Gala2_WGS',
#         'phsId': 'phs000920'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'atrial fibrillation',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_CVD_AF_VAFAR_Arrays',
#         'phsId': 'phs000997'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'atrial fibrillation',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_CVD_AF_VAFAR_WES',
#         'phsId': 'phs000997'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'atrial fibrillation',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_CVD_AFib_Vanderbilt-Ablation_WGS',
#         'phsId': 'phs000997'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'HMB-IRB',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'atrial fibrillation',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Baylor_CVD_AFib_VAFAR_HMB-IRB_WGS',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'cardiovascular system disease',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_CVD_AFib_MGH_WGS',
#         'phsId': 'phs001062'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'atrial fibrillation',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_CVD_AF_Ellinor_MGH_Arrays',
#         'phsId': 'phs001062'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'HMB-IRB',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'cardiovascular system disease',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Baylor_CVD_ARIC',
#         'phsId': 'phs001211'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-DRC-IRB-NPU',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'type 1 diabetes mellitus',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_WashU_AI_T1D_T1DGC_WGS',
#         'phsId': 'phs001222'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU-IRB',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'atherosclerosis',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_WashU_CVD_EOCAD_WashU-CAD_GRU-IRB_WGS',
#         'phsId': 'phs001227'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-ATHSCL-IRB-MDS',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'atherosclerosis',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_WashU_CVD_EOCAD_WashU-CAD_DS_WGS',
#         'phsId': 'phs001227'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-CARD-MDS-GSO',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'cardiovascular system disease',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_CVD_EOCAD_VIRGO_WGS',
#         'phsId': 'phs001259'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'HMB-NPU',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'cardiovascular system disease',
#         'library:studyDesign': 'Prospective Longitudinal Cohort',
#         'name': 'AnVIL_CCDG_Baylor_CVD_EOCAD_SoL_WGS',
#         'phsId': 'phs001395'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'myocardial infarction',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_MI_BRAVE_GRU_WES',
#         'phsId': 'phs001398'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'myocardial infarction',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_CVD_Stroke_BRAVE_WGS',
#         'phsId': 'phs001398'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-CVD-IRB-COL-MDS',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'cardiovascular system disease',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_CVD_EOCAD_TaiChi_WGS',
#         'phsId': 'phs001487'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_AUSRMB_DS-EAED-MDS-NPU-IRB_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USAMON_HMB_NPU_MDS_GSA-MD',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USAMSS_DS_EP_NEURO_MDS_GSA-MD',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_BRAUSP_DS_MDS_NPU_GSA-MD',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_HKOSB_GRU_GSA-MD',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USAMGH_HMB_MDS_GSA-MD',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_BRAUSP_DS_MDS_NPU_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_AUSRMB_DS-EAED-MDS-NPU-IRB_GSA-MD',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USALCH_HMB_MDS_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USAMON_HMB_NPU_MDS_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_AUTMUV_DS_NS_MDS_NPU_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_AUTMUV_DS_NS_MDS_NPU_GSA-MD',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_AUSALF_HMB_IRB_GSRS_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_TWNCGM_HMB-NPU-ADULTS_GSA-MD',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USALCH_HMB_MDS_GSA-MD',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_CANCAL_GRU_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_GHAKNT_GRU_GSA-MD',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USACCF_HMB-MDS_GSA-MD',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU-NPU',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USAMON_GRU_NPU_WES',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_AUTMUV_DS_NS_NPU_ADLT_GSA-MD',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_ZAFAGN_DS-EPI-COMO-MDS_GSA-MD',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_KENKIL_GRU_GSA-MD',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_AUSALF_HMB_IRB_GSRS_GSA-MD',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_AUTMUV_DS_NS_NPU_ADLT_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU-NPU',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USABLC_GRU-NPU_WES',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'HMB-MDS',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USAMGH_MGBB_HMB_MDS_WES',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'EPIL_BRAIN_AB_INTEL_DIS_MDS',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_AUSAUS_EPI_BA_ID_MDS_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_TURBZU_GRU_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_DEUUPM_HMB_MDS_WES',
#         'phsId': 'phs001498'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_FRALYU_HMB_WES',
#         'phsId': 'phs001498'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'HMB-IRB-MDS',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_CHEUBB_HMB_IRB_MDS_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_BELATW_GRU_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_HKOSB_GRU_WES',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_GBRUNL_GRU_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'HMB-NPU-MDS',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_LTUUHK_HMB_NPU_MDS_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USAUPN_GRU_NPU_WES',
#         'phsId': 'phs001498'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_DEUULG_GRU_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-NEURO-MDS',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USACCH_DS_NEURO_MDS_WES',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_GHAKNT_GRU_WES',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USAUPN_GRU_WES',
#         'phsId': 'phs001498'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-NPD-IRB-NPU',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_JPNRKI_DS_NPD_IRB_NPU_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-NEURO-AD-NPU',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_TURIBU_DS_NEURO_AD_NPU_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'HMB-NPU-MDS',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_FINUVH_HMB_NPU_MDS_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_CZEMTH_GRU_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USAFEB_GRU_WES',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-NEURO-MDS',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USANCH_DS_NEURO_MDS_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'HMB-MDS',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USAMGH_HMB_MDS_WES',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-EP-MDS',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USACRW_DS_EP_MDS_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_KENKIL_GRU_WES',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USAEGP_GRU_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-SEIZD',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USACRW_DS_SEIZD_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-EPI-COMO-MDS',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_ZAFAGN_DS-EPI-COMO-MDS_WES',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'HMB-MDS',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_HRVUZG_HMB_MDS_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_JPNFKA_GRU_WES',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-EP-ETIOLOGY-MDS',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_GBRUNL_EP_ETIOLOGY_MDS_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-EARET-MDS',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_GBRUCL_DS_EARET_MDS_WES',
#         'phsId': 'phs001489'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USAVANcontrols_HMB-GSO_WES',
#         'phsId': 'phs001498'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'HMB-GSO',
#         'library:datatype': 'Exome',
#         'library:indication': 'epilepsy',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_NP_Epilepsy_USAVAN_HMB-GSO_WES',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'HMB-IRB-PUB',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'coronary artery disease',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_WashU_CVD_EOCAD_Penn_WGS',
#         'phsId': 'phs001502'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': '',
#         'library:datatype': 'TBD',
#         'library:indication': 'atrial fibrillation',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_TOPMed_WashU_CVD_Afib_Penn_WGS',
#         'phsId': 'phs001502'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'atrial fibrillation',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_CVD_AFib_AFLMU_WGS',
#         'phsId': 'phs001543'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'atrial fibrillation',
#         'library:studyDesign': 'Prospective Longitudinal Cohort',
#         'name': 'AnVIL_CCDG_Broad_CVD_AFib_MPP_WGS',
#         'phsId': 'phs001544'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'atrial fibrillation',
#         'library:studyDesign': 'Prospective Longitudinal Cohort',
#         'name': 'AnVIL_CCDG_Broad_CVD_AFib_Intermountain_WGS',
#         'phsId': 'phs001545'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'atrial fibrillation',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_CVD_AF_Natale_TCAI_WES',
#         'phsId': 'phs001546'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'atrial fibrillation',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_CVD_AFib_GENAF_WGS',
#         'phsId': 'phs001547'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'myocardial infarction',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_TOPMED_Broad_CVD_EOCAD_PROMIS_WGS',
#         'phsId': 'phs001569'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'myocardial infarction',
#         'library:studyDesign': 'Case-Control',
#         'name': 'ANVIL_CCDG_Broad_CVD_EOCAD_PROMIS_ARRAY',
#         'phsId': 'phs001569'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'myocardial infarction',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_CVD_EOCAD_PROMIS_WGS',
#         'phsId': 'phs001569'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'myocardial infarction',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_CVD_PROMIS_GRU_WES',
#         'phsId': 'phs001569'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU-IRB-NPU',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'coronary artery disease',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_WashU_CVD_EOCAD_METSIM_WGS',
#         'phsId': 'phs001579'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-CVD',
#         'library:datatype': 'Exome',
#         'library:indication': 'myocardial infarction',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_MI_ATVB_DS_CVD_WES',
#         'phsId': 'phs001592'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'atrial fibrillation',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_CVD_AFib_JHU_WGS',
#         'phsId': 'phs001598'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-CVD-IRB',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'heart and blood vessel disease',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_WashU_CVD_EOCAD_Duke_WGS',
#         'phsId': 'phs001506'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'atrial fibrillation',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_CVD_AFib_Duke_WGS',
#         'phsId': 'phs001600'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': '',
#         'library:datatype': 'TBD',
#         'library:indication': 'atrial fibrillation',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_TOPMed_WashU_CVD_Afib_Duke_WGS',
#         'phsId': 'phs001600'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'atrial fibrillation',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_CVD_AFib_Penn_WGS',
#         'phsId': 'phs001502'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'atrial fibrillation',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Baylor_CVD_AFib_BioVU_WGS',
#         'phsId': 'phs001624'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'HMB-GSO',
#         'library:datatype': 'Exome',
#         'library:indication': 'atrial fibrillation',
#         'library:studyDesign': 'Case Set',
#         'name': 'AnVIL_CCDG_Broad_CVD_AF_BioVU_HMB_GSO_WES',
#         'phsId': 'phs001624'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'HMB-GSO',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'coronary artery disease',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_WashU_CVD_EOCAD_BioVu_WGS',
#         'phsId': 'phs001873'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'HMB-GSO',
#         'library:datatype': 'TBD',
#         'library:indication': 'inflammatory bowel disease',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_Broad_CVD_AF_BioVU_HMB_GSO_Arrays',
#         'phsId': 'phs001624'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': '',
#         'library:datatype': 'TBD',
#         'library:indication': 'atrial fibrillation',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CCDG_TOPMed_WashU_CVD_Afib_BioVu_WGS',
#         'phsId': 'phs001624'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'HMB-MDS',
#         'library:datatype': 'Exome',
#         'library:indication': 'inflammatory bowel disease',
#         'library:studyDesign': 'Case-Control',
#         'name': 'anvil_ccdg_broad_ai_ibd_daly_niddk_cho_wes',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'HMB',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'inflammatory bowel disease',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_CCDG_Broad_AI_IBD_Brant_DS-IBD_WGS',
#         'phsId': 'phs001642'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'inflammatory bowel disease',
#         'library:studyDesign': 'TBD',
#         'name': 'anvil_ccdg_broad_ai_ibd_daly_xavier_share_gsa',
#         'phsId': 'phs001642'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'inflammatory bowel disease',
#         'library:studyDesign': 'Case-Control',
#         'name': 'anvil_nhgri_broad_ibd_daly_kugathasan_wes',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-IBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'inflammatory bowel disease',
#         'library:studyDesign': 'Case-Control',
#         'name': 'anvil_ccdg_broad_ai_ibd_niddk_daly_silverberg_wes',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'inflammatory bowel disease',
#         'library:studyDesign': 'Case-Control',
#         'name': 'anvil_ccdg_broad_ai_ibd_alm_gmc_wes',
#         'phsId': 'phs001642'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-GI',
#         'library:datatype': 'Exome',
#         'library:indication': 'inflammatory bowel disease',
#         'library:studyDesign': 'Case-Control',
#         'name': 'anvil_ccdg_broad_ai_ibd_daly_vermeire_wes',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'inflammatory bowel disease',
#         'library:studyDesign': 'TBD',
#         'name': 'anvil_ccdg_broad_ai_ibd_daly_newberry_share_gsa',
#         'phsId': 'phs001642'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'inflammatory bowel disease',
#         'library:studyDesign': 'Case-Control',
#         'name': 'anvil_ccdg_broad_ai_ibd_daly_franchimont_gsa',
#         'phsId': 'phs001642'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'inflammatory bowel disease',
#         'library:studyDesign': 'Case-Control',
#         'name': 'anvil_ccdg_broad_ai_ibd_daly_mcgovern_gsa',
#         'phsId': 'phs001642'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'DS-IBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'inflammatory bowel disease',
#         'library:studyDesign': 'Case Set',
#         'name': 'anvil_ccdg_broad_ai_ibd_daly_faubion_share_wes',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'inflammatory bowel disease',
#         'library:studyDesign': 'TBD',
#         'name': 'anvil_ccdg_broad_ai_ibd_daly_faubion_share_gsa',
#         'phsId': 'phs001642'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'inflammatory bowel disease',
#         'library:studyDesign': 'TBD',
#         'name': 'anvil_ccdg_broad_ai_ibd_daly_pekow_share_gsa',
#         'phsId': 'phs001642'},
#     {   'consortium': 'CCDG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Genotyping Array',
#         'library:indication': 'inflammatory bowel disease',
#         'library:studyDesign': 'TBD',
# ...
#         'library:indication': 'Mendelian',
#         'library:studyDesign': 'Parent-Offspring Trios',
#         'name': 'AnVIL_CMG_Broad_Muscle_Bonnemann_WGS',
#         'phsId': 'phs001272'},
#     {   'consortium': 'CMG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Exome',
#         'library:indication': 'Mendelian',
#         'library:studyDesign': 'Parent-Offspring Trios',
#         'name': 'AnVIL_CMG_Broad_Muscle_Bonnemann_WES',
#         'phsId': 'phs001272'},
#     {   'consortium': 'CMG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'Mendelian',
#         'library:studyDesign': 'Parent-Offspring Trios',
#         'name': 'AnVIL_CMG_Broad_Orphan_Manton_WGS',
#         'phsId': 'phs001272'},
#     {   'consortium': 'CMG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Exome',
#         'library:indication': 'Mendelian',
#         'library:studyDesign': 'Parent-Offspring Trios',
#         'name': 'AnVIL_CMG_Broad_Brain_Sherr_WES',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CMG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Exome',
#         'library:indication': 'Mendelian',
#         'library:studyDesign': 'Parent-Offspring Trios',
#         'name': 'AnVIL_CMG_Broad_Blood_Fleming_WES',
#         'phsId': 'phs001272'},
#     {   'consortium': 'CMG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'Mendelian disorders',
#         'library:studyDesign': 'TBD',
#         'name': 'ANVIL_CMG_Broad_Orphan_Jueppner_WES',
#         'phsId': 'phs001272'},
#     {   'consortium': 'CMG',
#         'library:dataUseRestriction': 'HMB-MDS',
#         'library:datatype': 'Exome',
#         'library:indication': 'Mendelian',
#         'library:studyDesign': 'Parent-Offspring Trios',
#         'name': 'AnVIL_CMG_Broad_Muscle_Ravenscroft_WES',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CMG',
#         'library:dataUseRestriction': 'HMB-MDS',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'Mendelian',
#         'library:studyDesign': 'Parent-Offspring Trios',
#         'name': 'AnVIL_CMG_Broad_Orphan_VCGS-White_WGS',
#         'phsId': 'phs001272'},
#     {   'consortium': 'CMG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'Mendelian disorders',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CMG_Broad_Orphan_Lerner-Ellis_WES',
#         'phsId': 'phs001272'},
#     {   'consortium': 'CMG',
#         'library:dataUseRestriction': 'HMB-MDS',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'Mendelian',
#         'library:studyDesign': 'Parent-Offspring Trios',
#         'name': 'AnVIL_CMG_Broad_Muscle_Myoseq_WGS',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CMG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'Mendelian',
#         'library:studyDesign': 'Parent-Offspring Trios',
#         'name': 'AnVIL_CMG_Broad_Muscle_Kang_WGS',
#         'phsId': 'phs001272'},
#     {   'consortium': 'CMG',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'Mendelian',
#         'library:studyDesign': 'Parent-Offspring Trios',
#         'name': 'AnVIL_CMG_Broad_Eye_Pierce_WGS',
#         'phsId': 'phs001272'},
#     {   'consortium': 'CMG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'mendelian disorders',
#         'library:studyDesign': 'TBD',
#         'name': 'ANVIL_CMG_BROAD_BRAIN_SHERR_WGS',
#         'phsId': 'phs001272'},
#     {   'consortium': 'CMG',
#         'library:dataUseRestriction': 'Consortia Access Only',
#         'library:datatype': 'Exome',
#         'library:indication': 'Mendelian',
#         'library:studyDesign': 'Parent-Offspring Trios',
#         'name': 'AnVIL_CMG_Broad_Orphan_Scott_WES',
#         'phsId': 'phs001272'},
#     {   'consortium': 'CMG',
#         'library:dataUseRestriction': 'HMB-MDS',
#         'library:datatype': 'Exome',
#         'library:indication': 'Mendelian',
#         'library:studyDesign': 'Parent-Offspring Trios',
#         'name': 'AnVIL_CMG_Broad_Orphan_VCGS-White_WES',
#         'phsId': 'phs001272'},
#     {   'consortium': 'CMG',
#         'library:dataUseRestriction': 'TBD',
#         'library:datatype': 'Exome',
#         'library:indication': 'mendelian disorders',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CMG_Broad_Brain_Walsh_WES',
#         'phsId': 'TBD'},
#     {   'consortium': 'CMG',
#         'library:dataUseRestriction': 'DS-NIC-EMP-LENF',
#         'library:datatype': 'Exome',
#         'library:indication': 'Mendelian',
#         'library:studyDesign': 'Parent-Offspring Trios',
#         'name': 'AnVIL_CMG_Broad_Muscle_KNC_WES',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'CMH',
#         'library:dataUseRestriction': 'DS-PEDD-IRB',
#         'library:datatype': 'TBD',
#         'library:indication': 'pediatric disease',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CMH_GAFK_scRNA',
#         'phsId': 'phs002206'},
#     {   'consortium': 'CMH',
#         'library:dataUseRestriction': 'DS-PEDD-IRB',
#         'library:datatype': 'TBD',
#         'library:indication': 'pediatric disease',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CMH_GAFK_GS-long-read',
#         'phsId': 'phs002206'},
#     {   'consortium': 'CMH',
#         'library:dataUseRestriction': 'DS-PEDD-IRB',
#         'library:datatype': 'TBD',
#         'library:indication': 'pediatric disease',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CMH_GAFK_WGBS',
#         'phsId': 'phs002206'},
#     {   'consortium': 'CMH',
#         'library:dataUseRestriction': 'DS-PEDD-IRB',
#         'library:datatype': 'TBD',
#         'library:indication': 'pediatric disease',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CMH_GAFK_GS-linked-read',
#         'phsId': 'phs002206'},
#     {   'consortium': 'CMH',
#         'library:dataUseRestriction': 'DS-PEDD-IRB',
#         'library:datatype': 'TBD',
#         'library:indication': 'pediatric disease',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CMH_GAFK_SCATAC',
#         'phsId': 'phs002206'},
#     {   'consortium': 'Convergent Neuroscience',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Single Cell RNAseq, Pooled Genomic Seq',
#         'library:indication': 'CIRM iPSC Repository',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_NIMH_CIRM_FCDI_ConvergentNeuro_McCarroll_Eggan_GRU_Arrays',
#         'phsId': 'phs002032'},
#     {   'consortium': 'Convergent Neuroscience',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Whole Genome',
#         'library:indication': '--',
#         'library:studyDesign': 'Prospective Longitudinal Cohort',
#         'name': 'AnVIL_NIMH_Broad_ConvergentNeuro_McCarroll_Eggan_CIRM_GRU_WGS',
#         'phsId': 'phs002032'},
#     {   'consortium': 'Convergent Neuroscience',
#         'library:dataUseRestriction': 'DS-SMA-MDS',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'Spinal Muscular Atrophy',
#         'library:studyDesign': 'Prospective Longitudinal Cohort',
#         'name': 'AnVIL_NIMH_Broad_ConvergentNeuro_McCarroll_Eggan_Finkel_SMA_DS_WGS',
#         'phsId': 'phs002032'},
#     {   'consortium': 'Convergent Neuroscience',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'TBD',
#         'library:indication': 'Unspecified',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_NIMH_Broad_ConvergentNeuro_McCarroll_Eggan_CIRM_GRU_VillageData',
#         'phsId': 'phs002032'},
#     {   'consortium': 'CSER',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'TBD',
#         'library:indication': 'Unspecified',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CSER_CHARM_GRU',
#         'phsId': 'TBD'},
#     {   'consortium': 'CSER',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'TBD',
#         'library:indication': 'Unspecified',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CSER_NCGENES2_GRU',
#         'phsId': 'TBD'},
#     {   'consortium': 'CSER',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'TBD',
#         'library:indication': 'Unspecified',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CSER_KidsCanSeq_GRU',
#         'phsId': 'TBD'},
#     {   'consortium': 'CSER',
#         'library:dataUseRestriction': 'HMB',
#         'library:datatype': 'TBD',
#         'library:indication': 'Unspecified',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CSER_NYCKIDSSEQ_HMB',
#         'phsId': 'TBD'},
#     {   'consortium': 'CSER',
#         'library:dataUseRestriction': '',
#         'library:datatype': 'TBD',
#         'library:indication': 'Unspecified',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CSER_UW_DCC',
#         'phsId': 'TBD'},
#     {   'consortium': 'CSER',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'TBD',
#         'library:indication': 'Unspecified',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CSER_SouthSeq_GRU',
#         'phsId': 'TBD'},
#     {   'consortium': 'CSER',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'TBD',
#         'library:indication': 'Unspecified',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_CSER_ClinSeq_GRU',
#         'phsId': 'TBD'},
#     {   'consortium': 'eMERGE',
#         'library:dataUseRestriction': '',
#         'library:datatype': 'TBD',
#         'library:indication': 'Unspecified',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_eMERGE_GWAS',
#         'phsId': 'phs001584'},
#     {   'consortium': 'eMERGE',
#         'library:dataUseRestriction': '',
#         'library:datatype': 'TBD',
#         'library:indication': 'Unspecified',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_eMERGE_PGRNseq',
#         'phsId': 'phs001616'},
#     {   'consortium': 'eMERGE',
#         'library:dataUseRestriction': '',
#         'library:datatype': 'TBD',
#         'library:indication': 'Unspecified',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_eMERGE_PRS_Arrays',
#         'phsId': 'Registration Pending'},
#     {   'consortium': 'GTEx',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'TBD',
#         'library:indication': 'Unspecified',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_GTEx_V9_hg38',
#         'phsId': 'phs000424'},
#     {   'consortium': 'GTEx',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'TBD',
#         'library:indication': 'Unspecified',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_GTEx_V7_hg19',
#         'phsId': 'phs000424'},
#     {   'consortium': 'GTEx',
#         'library:dataUseRestriction': 'NRES',
#         'library:datatype': 'TBD',
#         'library:indication': 'Unspecified',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_GTEx_public_data',
#         'phsId': 'None'},
#     {   'consortium': 'GTEx',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Whole Genome, Exome, RNAseq',
#         'library:indication': 'None',
#         'library:studyDesign': 'Family/Twins/Trios',
#         'name': 'AnVIL_GTEx_V8_hg38',
#         'phsId': 'phs000424'},
#     {   'consortium': 'GTEx',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'Mendelian disorders',
#         'library:studyDesign': 'Cross-Sectional',
#         'name': 'AnVIL_GTEx_Somatic_WGS',
#         'phsId': 'TBD'},
#     {   'consortium': 'GTEx',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Methylation Array',
#         'library:indication': 'epigenetic variation',
#         'library:studyDesign': 'Control Set',
#         'name': 'AnVIL_GTEx_BCM_GRU_CoRSIVs',
#         'phsId': 'TBD'},
#     {   'consortium': 'HPRC',
#         'library:dataUseRestriction': 'NRES',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'None',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_HPRC',
#         'phsId': 'None'},
#     {   'consortium': 'PAGE',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'population',
#         'library:studyDesign': 'Prospective Longitudinal Cohort',
#         'name': 'AnVIL_PAGE_BioMe_GRU_WGS',
#         'phsId': 'phs000925'},
#     {   'consortium': 'PAGE',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'population',
#         'library:studyDesign': 'Control Set',
#         'name': 'AnVIL_PAGE_Stanford_Global_Reference_Panel_GRU_WGS',
#         'phsId': 'phs001033'},
#     {   'consortium': 'PAGE',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'population',
#         'library:studyDesign': 'Case-Control',
#         'name': 'AnVIL_PAGE_MEC_GRU_WGS',
#         'phsId': 'phs000220'},
#     {   'consortium': 'PAGE',
#         'library:dataUseRestriction': 'HMB-IRB',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'population',
#         'library:studyDesign': 'Prospective Longitudinal Cohort',
#         'name': 'AnVIL_PAGE_WHI_HMB-IRB_WGS',
#         'phsId': 'phs000227'},
#     {   'consortium': 'PAGE',
#         'library:dataUseRestriction': 'HMB',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'Unspecified',
#         'library:studyDesign': 'TBD',
#         'name': 'AnVIL_PAGE_SoL_HMB_WGS',
#         'phsId': 'TBD'},
#     {   'consortium': 'T2T',
#         'library:dataUseRestriction': 'NRES',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'None',
#         'library:studyDesign': 'Parent-Offspring Trios',
#         'name': 'AnVIL_T2T',
#         'phsId': 'None'},
#     {   'consortium': 'WGSPD1',
#         'library:dataUseRestriction': 'DS-MLHLTH-MDS',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'Schizophrenia cases and controls',
#         'library:studyDesign': 'Case-control',
#         'name': 'AnVIL_NIMH_Broad_WGSPD1_McCarroll_Escamilla_DS_WGS',
#         'phsId': 'phs002041'},
#     {   'consortium': 'WGSPD1',
#         'library:dataUseRestriction': 'DS-SZRD-MDS',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'Schizophrenia cases and controls',
#         'library:studyDesign': 'Case-control',
#         'name': 'AnVIL_NIMH_Broad_WGSPD1_McCarroll_Braff_DS_WGS',
#         'phsId': 'phs002041'},
#     {   'consortium': 'WGSPD1',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'Schizophrenia and Bipolar Disorder cases and '
#                               'controls',
#         'library:studyDesign': 'Case-control',
#         'name': 'AnVIL_NIMH_Broad_WGSPD1_McCarroll_Pato_GRU_WGS',
#         'phsId': 'phs002041'},
#     {   'consortium': 'WGSPD1',
#         'library:dataUseRestriction': 'GRU',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'Schizophrenia and Bipolar Disorder cases and '
#                               'controls',
#         'library:studyDesign': 'Case-control',
#         'name': 'AnVIL_NIMH_Broad_WGSPD1_McCarroll_Pato_GRU_10XLRGenomes',
#         'phsId': 'phs002041'},
#     {   'consortium': 'WGSPD1',
#         'library:dataUseRestriction': 'DS-SZRD-MDS',
#         'library:datatype': 'Whole Genome',
#         'library:indication': 'Schizophrenia cases and controls',
#         'library:studyDesign': 'Case-control',
#         'name': 'AnVIL_NIMH_Broad_WGSPD1_McCarroll_Braff_DS_10XLRGenomes',
#         'phsId': 'phs002041'}]
