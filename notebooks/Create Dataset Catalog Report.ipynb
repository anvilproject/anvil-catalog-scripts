# %% [markdown]
# # Imports

# %%
from datetime import datetime
import firecloud.api as FAPI
import json
import os
import pandas as pd
import pprint

print(FAPI.whoami())
pp = pprint.PrettyPrinter(indent=4)

## TODO Merge in Dave Using
## TODO Read / Write from "reports" dir
# Out:
# pet-117272931645288568532@terra-e36fcccd.iam.gserviceaccount.com

# %%
BILLING_PROJECT_ID = os.environ['WORKSPACE_NAMESPACE']
WORKSPACE = os.environ['WORKSPACE_NAME']
WORKSPACE_BUCKET = os.environ['WORKSPACE_BUCKET']

CATALOG_WORKSPACE_NAMESPACE = "anvil-datastorage"

print("Copy files:")
# print(WORKSPACE_BUCKET)
# !gsutil cp $WORKSPACE_BUCKET/attributes_for_AnVIL_workspaces_update_210217.csv  .
# !gsutil cp $WORKSPACE_BUCKET/attributes_for_AnVIL_workspaces_220204.csv  .
# !gsutil cp $WORKSPACE_BUCKET/anvil_workspaces_tags_220211.tsv  .
# !gsutil cp $WORKSPACE_BUCKET/AnVIL_Data_Ingestion_Attributes_210225-Dave-Using.csv  .
# !gsutil cp $WORKSPACE_BUCKET/AnVILCatalogWorkspacesInput-2022-03-08.csv  .




print("List all files:")
# !ls 
# print(BILLING_PROJECT_ID)

def getRequestorPays(bucketName):
    result = !gsutil -u anvil-jamboree-june-10-2020 requesterpays get  gs://$bucketName
    return ( "Enabled" in result[0])

def getBucketSize(bucketName):
    result = !gsutil -u anvil-jamboree-june-10-2020 du -s gs://$bucketName
    return result[0].split()[0]
  

# print(getBucketSize('fc-56ac46ea-efc4-4683-b6d5-6d95bed41c5e'))
# Out:
# Copy files:
# Copying gs://fc-cb5be780-171f-49d4-9116-b77fd2237d0b/attributes_for_AnVIL_workspaces_220204.csv...
# / [1 files][709.1 KiB/709.1 KiB]
# Operation completed over 1 objects/709.1 KiB.
# Copying gs://fc-cb5be780-171f-49d4-9116-b77fd2237d0b/AnVILCatalogWorkspacesInput-2022-03-08.csv...
# / [1 files][ 50.2 KiB/ 50.2 KiB]
# Operation completed over 1 objects/50.2 KiB.
# List all files:
# 'Add Workspace Writer.ipynb'
#  AnVILCatalogWorkspacesInput-2022-03-07.csv
#  AnVILCatalogWorkspacesInput-2022-03-08.csv
#  AnVILCatalogWorkspacesPublicMetadata-2022-02-25.csv
#  AnVILCatalogWorkspacesPublicMetadata-2022-03-08.csv
#  AnVIL_CMG_Broad_Muscle_KNC_WGS_2022-03-03T07:08:33.763296.json
#  AnVIL_CMG_Broad_Muscle_KNC_WGS_2022-03-03T07:10:26.198347.json
#  AnVIL_Data_Ingestion_Attributes_210225-Dave-Using.csv
#  AnVIL_Data_Ingestion_Attributes_210225-November-2-2021-1_17-PM-Dave_Using.csv
# 'AnVIL Dataset Catalog Notebook.ipynb'
# 'AnVIL Dataset Catalog Test.ipynb'
#  anvil_workspaces_tags_220211.tsv
#  attributes_for_AnVIL_workspaces_220204.csv
#  attributes_for_AnVIL_workspaces_update_210217.csv
# 'Catalog Spreadsheet vs API Diff Report.ipynb'
# 'Combine and Trim DaveUsing and TagSheet.ipynb'
# 'Create Dataset Catalog Report.ipynb'
# 'TCGA_LAML_hg38_OpenAccess_GDCDR-12-0_DATA_03-Mar-2022 (06:56:49.305641).json'
# 'TCGA_LAML_hg38_OpenAccess_GDCDR-12-0_DATA_03-Mar-2022 (06:58:04.398875).json'
#  TCGA_LAML_hg38_OpenAccess_GDCDR-12-0_DATA_2022-03-03T07:03:16.663543.json
#  TCGA_LAML_hg38_OpenAccess_GDCDR-12-0_DATA_2022-03-03T07:05:27.929056.json
#  TCGA_LAML_hg38_OpenAccess_GDCDR-12-0_DATA_2022-03-03T07:06:28.634137.json
# 'Tile DB Playground.ipynb'
# 'Update Workspace Attributes.ipynb'
# 'Update Workspace Tags.ipynb'

# %%
# dir(FAPI)
# help(FAPI)

# %%
## Get all workspaces we have access to
workspaces = FAPI.list_workspaces().json()


workspaceNames = set()
for w in workspaces:
    workspaceNames.add(w['workspace']['name'])
#pp.pprint(workspaces[1])

# %%
## Read in full workspaces list
attributesSheet = pd.read_csv('attributes_for_AnVIL_workspaces_220204.csv')
attributesSheet = attributesSheet[["name","consortium"]]
attributesSheet.set_index("name", inplace=True)


## Read in input list
input = pd.read_csv('AnVILCatalogWorkspacesInput-2022-03-08.csv')
input = input[["name","library:dataUseRestriction", "library:datatype", "library:indication", "phsId", "consortium","library:studyDesign"]]
input.set_index("name", inplace=True)




# print(workspaces)

## Filter out workpaces in the catalog that we have acces to
noAccess = set()
access = set()

for wName in attributesSheet.index.values:
    if wName not in workspaceNames:
        noAccess.add(wName)
    else:
        access.add(wName)

print("Total catalog workspaces:" , len(access)+len(noAccess))
print("Catalog workspaces in anvil_dev:",len(access))
print("")

print("Catalog Workspaces not in anvil_dev:", len(noAccess))
print("")
print(",\n".join(noAccess))
# Out:
# Total catalog workspaces: 535
# Catalog workspaces in anvil_dev: 516
#
# Catalog Workspaces not in anvil_dev: 19
#
# AnVIL_ccdg_asc_ndd_daly_talkowski_aleksic_asd_exome,
# AnVIL_CMG_Broad_MonogenicDiabetes_Philipson_WES,
# AnVIL_CMG_Broad_Muscle_INMR-Cooper_WGS,
# AnVIL_CMG_UWash_GRU_1,
# AnVIL_ccdg_asc_ndd_daly_talkowski_gargus_asd_exome,
# AnVIL_CCDG_NHGRI_Broad_ASD_Daly_phs000298_WES_vcf,
# AnVIL_CSER_NYCKIDSEQ,
# AnVIL_CMG_Broad_Genitourinary_Hirschhorn_WES,
# AnVIL_CMG_Broad_Kidney_Southampton_WES,
# AnVIL_CMG_Broad_Brain_Roscioli_WGS,
# ANVIL_GATK_10X,
# AnVIL_CMG_Broad_Kidney_Southampton_WGS,
# AnVIL_ccdg_asc_ndd_daly_talkowski_hultman_asd_exome,
# AnVIL_CMG_Broad_Rare_RGP_WGS,
# AnVIL_CSER_CSERUWDCC,
# AnVIL_CCDG_Broad_NP_Epilepsy_DEUUGS_DS_EP_MDS_WES,
# AnVIL_CMG_Broad_Orphan_Chung_WGS,
# AnVIL_CSER_NCGENES2,
# ANVIL_CMG_Broad_Genitourinary_Sinclair_WES

# %%
catalogArray = []

def extractDataTypes(workspace):
    attributes = w["workspace"]["attributes"]
    dataTypes = attributes.get("library:datatype","Unspecified")
    if isinstance(dataTypes, dict):
        return  ",".join(dataTypes["items"])  # cant use dataType.items as items is a function on dict
    else:
        return dataTypes
    
def extractTag(workspace, prefix):
    attributes = w["workspace"]["attributes"]
    tags = attributes.get("tag:tags","Unspecified")
    if isinstance(tags, dict):
        items = tags["items"]  # cant use dataType.items as items is a function on dict
        for tag in items:
            if tag.startswith(prefix):
                return tag.lstrip(prefix);
        return "Unspecified"
    else:
        return tags

def getSamples(workspace):
    return FAPI.get_entities(CATALOG_WORKSPACE_NAMESPACE, workspace,'sample').json()

def getSubjects(workspace):
    return FAPI.get_entities(CATALOG_WORKSPACE_NAMESPACE, workspace,'subject').json()

def getParticipants(workspace):
    return FAPI.get_entities(CATALOG_WORKSPACE_NAMESPACE, workspace,'participant').json()

def getEntityCount(entities, entity):
    e = entities.get(entity,"Unspecified")
    if isinstance(e, dict):
        return e['count']
    else:
        return 0
    

def getEntityCounts(workspace):
    entities = FAPI.list_entity_types(CATALOG_WORKSPACE_NAMESPACE,workspace).json()
    return {
        'discovery': getEntityCount(entities, "discovery"),
        'family': getEntityCount(entities, "family"),
        'participant': getEntityCount(entities, "participant"),
        'sample': getEntityCount(entities, "sample"),
        'subject': getEntityCount(entities, "subject")

    }

def extractTagSheetTag(workspaceName,tagName):
    if workspaceName in tagsSheet.index:
        return tagsSheet.at[workspaceName,tagName]
    else:
        return "Unspecified"

def extractTagSheetTagItem(workspaceName, tagName):
    if workspaceName in tagsSheet.index:
        items = tagsSheet.at[workspaceName,"tag:tags.items"]
        items = cleanUpDbGapTagSheetTag(items)
        items = items.split(",")
        for item in items:
            item = item.strip()
            if item.startswith(tagName):
                parts = item.split(":")
                if len(parts) == 2:
                    return parts[1]
                else:
                    return "Unspecified"
        ## Not found reuturn unspecified
        return "Unspecified"
    return "Unspecified"
    

def cleanUpDbGapTagSheetTag(tag):
    tag = tag.replace("'","")
    tag = tag.replace("[","")
    tag = tag.replace("]","")
    return tag

# %%
# cleanUpDbGapTagSheetTag(extractTagSheetTag("AnVIL_CCDG_Baylor_CVD_EOCAD_BioMe_WGS","tag:tags:dbGaP"))

# %%
#  'accessLevel': 'READER'
reader = set()
writer = set()
for w in workspaces:
    name = w['workspace']['name']
    if name in access:
#         print(w['accessLevel'], name )
        if w['accessLevel'] == "READER":
            reader.add(name)
        if w['accessLevel'] == "WRITER" or w['accessLevel'] == "OWNER":
            writer.add(name)

print("Catalog workspaces with reader access:",len(reader))
print("")

print("Catalog Workspaces with writer access:", len(writer))
     
print("Writer workspaces")
# print(writer)

print("Reader workspaces")
# print(reader)
# Out:
# Catalog workspaces with reader access: 0
#
# Catalog Workspaces with writer access: 516
# Writer workspaces
# Reader workspaces

# %%
wsCount = 1
for w in workspaces:
    name = w['workspace']['name']   
    if name in access and name in input.index:
        print("{wsCount} - {name}".format(wsCount=wsCount, name=name))
        wsCount = wsCount+1
#         if wsCount > 20:
#             break
#         attributes = w["workspace"]["attributes"]
        entityCounts = getEntityCounts(name)
        bucketName = w["workspace"]["bucketName"]
        wsVals = {
            'name': name,
            'consortium': input.at[name,"consortium"] ,
             #Extract consortia tag item
            'phsId': input.at[name,"phsId"] ,
            'library:dataUseRestriction':  input.at[name,"library:dataUseRestriction"] ,
            'library:indication':  input.at[name,"library:indication"] ,
            'library:studyDesign': input.at[name,"library:studyDesign"] ,
            'library:datatype.items': extractDataTypes(w),
            'subjectCount': entityCounts['subject'],
            'bucketName': bucketName,
            'sampleCount': entityCounts['sample'],
            'participantCount': entityCounts['participant'],
            'familyCount': entityCounts['family'],
            'discoveryCount': entityCounts['discovery'],
            'bucketSize': getBucketSize(bucketName),
            'requestorPays': getRequestorPays(bucketName),
            
        }
        catalogArray.append(wsVals)

catalogDF = pd.DataFrame(catalogArray)
catalogDF.set_index("name", inplace=True)
# print(catalogDF)

fileName = 'AnVILCatalogWorkspacesPublicMetadata-'+datetime.today().strftime('%Y-%m-%d')+".csv"

catalogDF.to_csv(fileName)
          
# !gsutil cp ./$fileName $WORKSPACE_BUCKET/notebooks
# Out:
# 1 - AnVIL_CMG_Broad_Muscle_KNC_WGS
# 2 - anvil_ccdg_broad_ai_ibd_daly_niddk_cho_wes
# 3 - AnVIL_CCDG_Broad_NP_Epilepsy_USABLC_GRU-NPU_WES
# 4 - AnVIL_CCDG_Broad_NP_Epilepsy_ITAUBG_DS_EPI_NPU_MDS_WES
# 5 - AnVIL_CMG_BaylorHopkins_HMB-NPU_WES
# 6 - AnVIL_CCDG_Broad_NP_Epilepsy_ITAUMC_DS_NEURO_MDS_GSA-MD
# 7 - ANVIL_CMG_UWASH_DS-HFA
# 8 - AnVIL_CCDG_Broad_NP_Epilepsy_USAMGH_MGBB_HMB_MDS_WES
# 9 - AnVIL_CCDG_Broad_NP_Epilepsy_USACRW_EPI_ASZ_MED_MDS_WES
# 10 - ANVIL_CMG_Broad_Muscle_Laing_WES
# 11 - AnVIL_CCDG_WashU_CVD_EOCAD_BioMe_WGS
# 12 - AnVIL_CCDG_Broad_NP_Epilepsy_ITAICB_HMB-NPU-MDS_GSA-MD
# 13 - AnVIL_CSER_CHARM_GRU
# 14 - AnVIL_ccdg_asc_ndd_daly_talkowski_chung_asd_exome
# 15 - AnVIL_CCDG_Broad_NP_Epilepsy_DEUPUM_HMB-MDS_GSA-MD
# 16 - AnVIL_CCDG_Broad_CVD_EOCAD_TaiChi_WGS
# 17 - AnVIL_CCDG_WashU_CVD_Eufam_WGS
# 18 - AnVIL_CCDG_Broad_AI_IBD_Brant_DS-IBD_WGS
# 19 - AnVIL_ccdg_asc_ndd_daly_talkowski_ac-boston_asd_exome
# 20 - AnVIL_CCDG_WashU_AI_T1D_T1DGC_WGS
# 21 - anvil_ccdg_broad_ai_ibd_daly_xavier_share_gsa
# 22 - AnVIL_CCDG_WashU_CVD_Wisconsin_WGS
# 23 - anvil_nhgri_broad_ibd_daly_kugathasan_wes
# 24 - AnVIL_CCDG_Broad_NP_Epilepsy_USAMON_GRU_GSA-MD
# 25 - AnVIL_CMG_Broad_Brain_Thaker_WES
# 26 - AnVIL_CCDG_Broad_NP_Epilepsy_AUSAUS_EPI_BA_ID_MDS_WES
# 27 - AnVIL_PAGE_BioMe_GRU_WGS
# 28 - AnVIL_CMG_Broad_Orphan_VCGS-White_WES
# 29 - anvil_ccdg_broad_ai_ibd_niddk_daly_silverberg_wes
# 30 - AnVIL_CCDG_Broad_CVD_AF_Darbar_UIC_Controls_WES
# 31 - AnVIL_CCDG_Broad_NP_Epilepsy_USACRW_DS_SEIZD_GSA-MD
# 32 - AnVIL_CCDG_Broad_NP_Epilepsy_FINKPH_EPIL_CO_MORBIDI_MDS_WES
# 33 - AnVIL_CCDG_Broad_NP_Epilepsy_DEUUTB_HMB-NPU-MDS_WES
# 34 - AnVIL_CCDG_Broad_CVD_AFib_Penn_WGS
# 35 - AnVIL_PAGE_Stanford_Global_Reference_Panel_GRU_WGS
# 36 - AnVIL_CMG_Broad_Muscle_Myoseq_WES
# 37 - AnVIL_CCDG_Broad_CVD_AF_Marcus_UCSF_Arrays
# 38 - AnVIL_CCDG_Broad_NP_Epilepsy_USAUPN_Marsh_GRU_WES
# 39 - anvil_ccdg_broad_ai_ibd_alm_gmc_wes
# 40 - AnVIL_CCDG_Broad_NP_Epilepsy_BELULB_DS-EP-NPU_WES
# 41 - AnVIL_CCDG_Broad_CVD_AF_Natale_TCAI_Arrays
# 42 - AnVIL_CMG_UWASH_HMB
# 43 - anvil_ccdg_broad_ai_ibd_daly_vermeire_wes
# 44 - anvil_ccdg_broad_ai_ibd_daly_newberry_share_gsa
# 45 - AnVIL_CMG_Broad_Heart_Ware_WES
# 46 - AnVIL_ccdg_asc_ndd_daly_talkowski_lattig_asd_exome
# 47 - AnVIL_CCDG_Broad_NP_Epilepsy_FINUVH_HMB-NPU-MDS_GSA-MD
# 48 - AnVIL_CCDG_Broad_NP_Epilepsy_TURBZU_GRU_WES
# 49 - AnVIL_CCDG_Broad_NP_Epilepsy_AUSRMB_DS-EAED-MDS-NPU-IRB_WES
# 50 - AnVIL_CCDG_WashU_CVD_EOCAD_Harvard-Costa-Rica_WGS
# 51 - AnVIL_NIMH_CIRM_FCDI_ConvergentNeuro_McCarroll_Eggan_GRU_Arrays
# 52 - anvil_ccdg_broad_ai_ibd_daly_franchimont_gsa
# 53 - AnVIL_CCDG_WashU_CVD_EOCAD_WashU-CAD_GRU-IRB_WGS
# 54 - anvil_ccdg_broad_ai_ibd_daly_mcgovern_gsa
# 55 - AnVIL_CCDG_Broad_CVD_EOCAD_VIRGO_WGS
# 56 - AnVIL_CCDG_Baylor_CVD_HemStroke_Yale_HMB_WGS
# 57 - AnVIL_CCDG_Broad_NP_Epilepsy_USAUPN_Penn_GRU_GSA-MD
# 58 - AnVIL_CCDG_Broad_CVD_AFib_AFLMU_WGS
# 59 - AnVIL_CMG_Broad_Muscle_Beggs_WES
# 60 - AnVIL_CCDG_Broad_NP_Epilepsy_DEUULG_GRU_GSA-MD
# 61 - AnVIL_CCDG_Broad_CVD_AFib_GENAF_WGS
# 62 - AnVIL_CCDG_Broad_NP_Epilepsy_DEUUPM_HMB_MDS_WES
# 63 - AnVIL_CCDG_WashU_CVD_EOCAD_METSIM_WGS
# 64 - AnVIL_CCDG_NYGC_NP_Autism_HFA_DS_WGS
# 65 - AnVIL_CMG_Broad_Blood_Sankaran_WGS
# 66 - AnVIL_CCDG_Broad_CVD_AFib_JHU_WGS
# 67 - AnVIL_CCDG_Broad_CVD_AFib_MPP_WGS
# 68 - AnVIL_CCDG_Broad_NP_Epilepsy_GBRSWU_CARDI_NEURO_GSA-MD
# 69 - AnVIL_CCDG_Broad_NP_Epilepsy_USAUPN_CHOP_GRU_NPU_GSA-MD
# 70 - AnVIL_CCDG_WashU_CVD_EOCAD_Finland-CHD_WGS
# 71 - AnVIL_ccdg_asc_ndd_daly_talkowski_puura_asd_exome
# 72 - AnVIL_CCDG_NYGC_NP_Alz_LOAD_WGS
# 73 - AnVIL_CCDG_Broad_NP_Epilepsy_GBRSWU_CARDI_NEURO_WES
# 74 - AnVIL_CCDG_Broad_NP_Epilepsy_FRALYU_HMB_WES
# 75 - AnVIL_CCDG_Broad_NP_Epilepsy_USAMON_HMB_NPU_MDS_GSA-MD
# 76 - AnVIL_CCDG_NYGC_NP_Autism_SSC_WGS
# 77 - anvil_ccdg_broad_ai_ibd_daly_faubion_share_wes
# 78 - anvil_ccdg_broad_ai_ibd_daly_faubion_share_gsa
# 79 - anvil_ccdg_broad_ai_ibd_daly_pekow_share_gsa
# 80 - AnVIL_CCDG_Broad_NP_Epilepsy_CHEUBB_HMB_IRB_MDS_WES
# 81 - anvil_ccdg_broad_ai_ibd_daly_vermeire_gsa
# 82 - AnVIL_CCDG_WashU_CVD_Kanazawa_WGS
# 83 - anvil_ccdg_broad_ai_ibd_daly_sands_msccr_gsa
# 84 - AnVIL_CCDG_WashU_CVD_EOCAD_Penn_WGS
# 85 - AnVIL_GTEx_Somatic_WGS
# 86 - AnVIL_CCDG_Broad_CVD_AF_EAST_WES
# 87 - AnVIL_CCDG_Broad_CVD_AF_Ellinor_MGH_WES
# 88 - AnVIL_CCDG_Broad_NP_Epilepsy_ITAUMR_GRU-NPU_GSA-MD
# 89 - AnVIL_CCDG_NYGC_NP_Autism_ACE2_DS-MDS_WGS
# 90 - AnVIL_PAGE_MEC_GRU_WGS
# 91 - AnVIL_CCDG_Broad_NP_Epilepsy_USAMSS_DS_EP_NEURO_MDS_GSA-MD
# 92 - AnVIL_CCDG_Broad_NP_Epilepsy_CANUTN_DS-EP_GSA-MD
# 93 - anvil_ccdg_broad_ai_ibd_niddk_daly_brant_wes
# 94 - AnVIL_CCDG_Broad_NP_Epilepsy_BELATW_GRU_WES
# 95 - AnVIL_CCDG_Broad_CVD_AF_VAFAR_Arrays
# 96 - AnVIL_CCDG_Broad_NP_Epilepsy_HKOSB_GRU_WES
# 97 - AnVIL_CCDG_Broad_CVD_AF_TMDU_Cases_WES
# 98 - AnVIL_CCDG_Broad_CVD_AF_VAFAR_WES
# 99 - AnVIL_eMERGE_PGRNseq
# 100 - AnVIL_CCDG_Broad_CVD_AFib_MGH_WGS
# 101 - AnVIL_CCDG_Broad_CVD_AF_Rienstra_WES
# 102 - AnVIL_ccdg_asc_ndd_daly_talkowski_kolevzon_asd_wgs
# 103 - AnVIL_CCDG_Broad_CVD_AF_Darbar_UIC_Controls_Arrays
# 104 - AnVIL_CCDG_Baylor_CVD_Oregon_SUDS_GRU_WGS
# 105 - AnVIL_CCDG_NYGC_AI_Asthma_Gala2_WGS
# 106 - AnVIL_CCDG_Broad_NP_Epilepsy_LEBABM_GRU_GSA-MD
# 107 - anvil_ccdg_broad_ai_ibd_daly_newberry_share_wes
# 108 - AnVIL_CCDG_WashU_CVD_PAGE_HMB-NPU_WGS
# 109 - AnVIL_CCDG_Broad_NP_Epilepsy_GBRUNL_GRU_WES
# 110 - AnVIL_CCDG_Broad_CVD_AF_Darbar_UIC_Cases_Arrays
# 111 - AnVIL_CCDG_Broad_MI_BRAVE_GRU_WES
# 112 - AnVIL_CCDG_Broad_NP_Epilepsy_ITAUMR_GRU_NPU_WES
# 113 - AnVIL_CCDG_Broad_NP_Epilepsy_LTUUHK_HMB_NPU_MDS_WES
# 114 - AnVIL_CCDG_Broad_CVD_AF_TMDU_Controls_WES
# 115 - ANVIL_CMG_UWASH_DS-BDIS
# 116 - AnVIL_CMG_UWash_DS-EP
# 117 - AnVIL_CCDG_Broad_NP_Epilepsy_USAUPN_GRU_NPU_WES
# 118 - anvil_ccdg_broad_ai_ibd_daly_pekow_share_wes
# 119 - AnVIL_CMH_GAFK_scRNA
# 120 - AnVIL_CCDG_Broad_NP_Epilepsy_GBRUNL_EP_ETIOLOGY_MDS_GSA-MD
# 121 - AnVIL_CCDG_WashU_CVD_Brazil-CVD_WGS
# 122 - anvil_ccdg_broad_ai_ibd_daly_sartor_share_wes
# 123 - AnVIL_CCDG_Broad_AI_IBD_McGovern_WGS
# 124 - AnVIL_CMG_Broad_Blood_Gazda_WGS
# 125 - AnVIL_CCDG_Broad_NP_Epilepsy_USAUPN_Marsh_GRU_NPU_WES
# 126 - anvil_ccdg_asc_ndd_daly_talkowski_schloesser_asd_gsa-md
# 127 - AnVIL_CCDG_WashU_CVD_EOCAD_BioImage_WGS
# 128 - AnVIL_CMG_Broad_Orphan_Estonia-Ounap_WES
# 129 - AnVIL_CCDG_Broad_NP_Epilepsy_IRLRCI_GRU_IRB_WES
# 130 - anvil_ccdg_broad_ai_ibd_daly_mccauley_wes
# 131 - AnVIL_CCDG_Broad_CVD_AF_Swiss_Cases_DS-MDS_Arrays
# 132 - AnVIL_CCDG_Broad_NP_Epilepsy_DEUULG_GRU_WES
# 133 - anvil_ccdg_asc_ndd_daly_talkowski_gurrieri_asd_exome
# 134 - ANVIL_CMG_BROAD_BRAIN_ENGLE_WES
# 135 - anvil_ccdg_broad_ai_ibd_daly_lewis_ccfa_wes
# 136 - AnVIL_CMG_Broad_Eye_Pierce_WES
# 137 - AnVIL_CCDG_WASHU_PAGE
# 138 - AnVIL_CMG_UWash_GRU-IRB
# 139 - anvil_ccdg_broad_ai_ibd_daly_xavier_kastner_fmf_wes
# 140 - anvil_ccdg_broad_ai_ibd_daly_brant_niddk_gsa
# 141 - AnVIL_CMG_Broad_Orphan_Estonia-Ounap_WGS
# 142 - anvil_ccdg_broad_ai_ibd_daly_duerr_niddk_gsa
# 143 - AnVIL_CMG_Broad_Muscle_Topf_WES
# 144 - AnVIL_HPRC
# 145 - anvil_ccdg_broad_ai_ibd_daly_sands_msccr_wes
# 146 - AnVIL_CCDG_Broad_NP_Epilepsy_USAVANControls_HMB-GSO_GSA-MD
# 147 - AnVIL_CMH_GAFK_GS-long-read
# 148 - AnVIL_CCDG_Broad_NP_Epilepsy_JPNFKA_GRU_GSA-MD
# 149 - AnVIL_T2T
# 150 - ANVIL_CMG_UWASH_DS-NBIA
# 151 - AnVIL_CCDG_Broad_NP_Epilepsy_AUSRMB_DS-EAED-MDS_WES
# 152 - AnVIL_CCDG_Broad_AI_IBD_Cho_WGS
# 153 - AnVIL_CCDG_NYGC_NP_Autism_SAGE_WGS
# 154 - AnVIL_CCDG_Broad_Spalletta_HMB_NPU_MDS_WES
# 155 - AnVIL_CCDG_NYGC_NP_Autism_PELPHREY_ACE_DS_WGS
# 156 - AnVIL_CCDG_Broad_AI_IBD_Newberry_WGS
# 157 - AnVIL_CCDG_Broad_MI_ATVB_DS_CVD_WES
# 158 - AnVIL_CMG_Broad_Blood_Sankaran_WES
# 159 - AnVIL_CCDG_Broad_NP_Epilepsy_USABCH_EPI_MUL_CON_MDS_GSA-MD
# 160 - AnVIL_CCDG_Broad_NP_Epilepsy_BRAUSP_DS_MDS_NPU_GSA-MD
# 161 - anvil_ccdg_broad_ai_ibd_daly_cho_niddk_gsa
# 162 - AnVIL_CCDG_Broad_CVD_AF_Natale_TCAI_WES
# 163 - AnVIL_CCDG_Broad_NP_Epilepsy_DEUPUM_HMB_MDS_WES
# 164 - AnVIL_CCDG_Broad_NP_Epilepsy_USACCH_DS_NEURO_MDS_WES
# 165 - AnVIL_CCDG_Broad_NP_Epilepsy_DEUUTB_HMB-NPU_MDS_GSA-MD
# 166 - AnVIL_ccdg_asc_ndd_daly_talkowski_menashe_asd_exome
# 167 - AnVIL_CCDG_Broad_NP_Epilepsy_HKOSB_GRU_GSA-MD
# 168 - AnVIL_ccdg_asc_ndd_daly_talkowski_AGRE_asd_exome
# 169 - AnVIL_CMG_Broad_Orphan_Sweetser_WES
# 170 - AnVIL_CCDG_Broad_NP_Epilepsy_GBRUCL_DS_EARET_MDS_GSA-MD
# 171 - AnVIL_CCDG_Broad_NP_Epilepsy_GHAKNT_GRU_WES
# 172 - AnVIL_ccdg_asc_ndd_daly_talkowski_domenici_asd_exome
# 173 - AnVIL_CMG_Broad_Brain_Walsh_WES
# 174 - anvil_ccdg_broad_ai_ibd_daly_rioux_niddk_wes
# 175 - AnVIL_CMG_Broad_Rare_RGP_WES
# 176 - 1000G-high-coverage-2019
# 177 - AnVIL_CCDG_Baylor_CVD_HemStroke_ERICH_WGS
# 178 - AnVIL_CCDG_NYGC_NP_Alz_EFIGA_WGS
# 179 - anvil_ccdg_broad_ai_ibd_daly_kupcinskas_wes
# 180 - AnVIL_CCDG_Broad_NP_Epilepsy_USACHP_GRU_GSA-MD
# 181 - AnVIL_CCDG_Broad_NP_Epilepsy_ITAIGI_GRU_WES
# 182 - AnVIL_CSER_NCGENES2_GRU
# 183 - AnVIL_CMH_GAFK_WGBS
# 184 - AnVIL_CSER_KidsCanSeq_GRU
# 185 - AnVIL_CCDG_Baylor_CVD_EOCAD_SoL_WGS
# 186 - AnVIL_CMG_Broad_Brain_NeuroDev_WES
# 187 - AnVIL_CCDG_Broad_CVD_AF_Roberts_UWO_WES
# 188 - AnVIL_CCDG_Broad_NP_Epilepsy_USAMGH_HMB_MDS_GSA-MD
# 189 - AnVIL_CCDG_Broad_NP_Epilepsy_USAUPN_GRU_WES
# 190 - AnVIL_CCDG_Broad_CVD_AF_ENGAGE_DS_WES
# 191 - AnVIL_CMG_Broad_Muscle_Kang_WES
# 192 - AnVIL_CCDG_Baylor_CVD_AFib_BioVU_WGS
# 193 - AnVIL_ccdg_asc_ndd_daly_talkowski_TASC_asd_exome
# 194 - AnVIL_CMG_Broad_Kidney_Hildebrandt_WES
# 195 - AnVIL_NIMH_Broad_WGSPD1_McCarroll_Pato_GRU_WGS
# 196 - AnVIL_CMH_GAFK_GS-linked-read
# 197 - AnVIL_CCDG_Broad_NP_Epilepsy_JPNRKI_DS_NPD_IRB_NPU_WES
# 198 - AnVIL_CCDG_Broad_NP_Epilepsy_USACRW_EPI_ASZ_MED_MDS_GSA-MD
# 199 - AnVIL_CCDG_Broad_CVD_AF_BioVU_HMB_GSO_WES
# 200 - AnVIL_CCDG_Broad_NP_Epilepsy_LEBABM_DS_Epilepsy_WES
# 201 - AnVIL_ccdg_asc_ndd_daly_talkowski_passos-bueno_asd_exome
# 202 - AnVIL_CMG_Broad_Muscle_OGrady_WES
# 203 - AnVIL_CCDG_WashU_CVD_Indiana_WGS
# 204 - AnVIL_CCDG_Broad_NP_Epilepsy_DEUUKB_HMB-NPU-MDS_GSA-MD
# 205 - AnVIL_CCDG_Broad_NP_Epilepsy_TURIBU_DS_NEURO_AD_NPU_WES
# 206 - AnVIL_CCDG_Broad_NP_Epilepsy_FINUVH_HMB_NPU_MDS_WES
# 207 - AnVIL_ccdg_asc_ndd_daly_talkowski_AGRE-FEMF_asd_exome
# 208 - anvil_ccdg_broad_ai_ibd_daly_bernstein_wes
# 209 - AnVIL_CCDG_Baylor_CVD_HemStroke_WashU_DS_WGS
# 210 - AnVIL_CCDG_Broad_MI_InStem_WES
# 211 - AnVIL_ccdg_asc_ndd_daly_talkowski_control_NIMH_asd_exome
# 212 - AnVIL_CCDG_Broad_NP_Epilepsy_USABCH_EPI_MUL_CON_MDS_WES
# 213 - AnVIL_CCDG_Broad_NP_Epilepsy_CZEMTH_GRU_WES
# 214 - AnVIL_CCDG_Broad_NP_Epilepsy_USABLC_GRU-NPU_GSA-MD
# 215 - AnVIL_CCDG_Baylor_CVD_HemStroke_Duke_DS_WGS
# 216 - AnVIL_eMERGE_PRS_Arrays
# 217 - AnVIL_CCDG_Broad_NP_Epilepsy_BRAUSP_DS_MDS_NPU_WES
# 218 - AnVIL_CCDG_Broad_CVD_AF_Swiss_Cases_DS-MDS_WES
# 219 - AnVIL_CCDG_TOPMED_Broad_CVD_EOCAD_PROMIS_WGS
# 220 - AnVIL_CMG_Broad_Brain_Gleeson_WES
# 221 - anvil_ccdg_broad_ai_ibd_daly_lewis_sparc_gsa
# 222 - AnVIL_CMG_UWash_GRU
# 223 - AnVIL_CCDG_NYGC_NP_Autism_PELPHREY_ACE_GRU_WGS
# 224 - anvil_nhgri_broad_ibd_daly_winter_wes
# 225 - anvil_ccdg_broad_ai_ibd_daly_louis_wes
# 226 - ANVIL_CMG_UWASH_HMB-IRB
# 227 - AnVIL_CMG_Broad_Brain_Muntoni_WES
# 228 - anvil_ccdg_broad_daly_igsr_1kg_twist_gsa
# 229 - AnVIL_CCDG_Broad_NP_Epilepsy_GBRUNL_GRU_GSA-MD
# 230 - AnVIL_PAGE_WHI_HMB-IRB_WGS
# 231 - AnVIL_CCDG_Broad_NP_Epilepsy_AUSRMB_DS-EAED-MDS-NPU-IRB_GSA-MD
# 232 - AnVIL_CCDG_Broad_NP_Epilepsy_CANUTN_DS-EP_WES
# 233 - AnVIL_CCDG_Broad_NP_Epilepsy_USAMON_GRU_GSRS_GSA-MD
# 234 - AnVIL_CCDG_Broad_NP_Epilepsy_FRALYU_HMB_GSA-MD
# 235 - AnVIL_CCDG_Broad_NP_Epilepsy_USANCH_DS_NEURO_MDS_GSA-MD
# 236 - AnVIL_CCDG_Broad_NP_Epilepsy_ITAUMC_DS_NEURO_MDS_WES
# 237 - AnVIL_CCDG_Broad_NP_Epilepsy_USAEGP_GRU_GSA-MD
# 238 - AnVIL_CCDG_Broad_NP_Epilepsy_USAMGH_MGBB_HMB_MDS_GSA-MD
# 239 - AnVIL_CCDG_Broad_NP_Epilepsy_HRVUZG_HMB-MDS_GSA-MD
# 240 - AnVIL_CCDG_WashU_CVD_SCCS_WGS
# 241 - AnVIL_CCDG_Broad_NP_Epilepsy_LEBABM_GRU_WES
# 242 - AnVIL_CCDG_Broad_NP_Epilepsy_USALCH_HMB_MDS_WES
# 243 - AnVIL_ccdg_asc_ndd_daly_talkowski_renieri_asd_exome
# 244 - anvil_ccdg_broad_ai_ibd_daly_chung_gider_wes
# 245 - AnVIL_CMG_Broad_Orphan_Chung_WES
# 246 - AnVIL_CCDG_Broad_CVD_AF_TMDU_Controls_Arrays
# 247 - AnVIL_CMG_Broad_Brain_Gleeson_WGS
# 248 - AnVIL_CCDG_Broad_NP_Epilepsy_USAMON_HMB_NPU_MDS_WES
# 249 - AnVIL_CMH_GAFK_SCATAC
# 250 - AnVIL_CCDG_Broad_NP_Epilepsy_USACHP_GRU_WES
# 251 - AnVIL_CCDG_Broad_NP_Epilepsy_AUTMUV_DS_NS_MDS_NPU_WES
# 252 - AnVIL_CCDG_Broad_NP_Epilepsy_NZLUTO_EPIL_BC_ID_MDS_GSA-MD
# 253 - ANVIL_CMG_BROAD_ORPHAN_SCOTT_WGS
# 254 - AnVIL_CCDG_Broad_NP_Epilepsy_HKGHKK_HMB_MDS_WES
# 255 - AnVIL_CCDG_Broad_NP_Autism_State-Sanders_WGS
# 256 - AnVIL_ccdg_asc_ndd_daly_talkowski_barbosa_asd_exome
# 257 - AnVIL_CMG_Broad_Orphan_Jueppner_WGS
# 258 - anvil_ccdg_broad_ai_ibd_niddk_daly_duerr_wes
# 259 - AnVIL_CCDG_WashU_CVD_EOCAD_WashU-CAD_DS_WGS
# 260 - ANVIL_CMG_YALE_DS-RARED
# 261 - AnVIL_CCDG_Broad_NP_Epilepsy_AUSRMB_DS-EAED-MDS_GSA-MD
# 262 - AnVIL_CCDG_Baylor_CVD_HemStroke_BNI_HMB_WGS
# 263 - AnVIL_CMG_Broad_Kidney_Hildebrandt_WGS
# 264 - AnVIL_CCDG_Broad_NP_Epilepsy_DEUUKL_HMB_WES
# 265 - AnVIL_ccdg_asc_ndd_daly_talkowski_herman_asd_exome
# 266 - AnVIL_CCDG_Broad_NP_Epilepsy_DEUUKL_HMB_GSA-MD
# 267 - AnVIL_CCDG_Broad_NP_Epilepsy_AUTMUV_DS_NS_MDS_NPU_GSA-MD
# 268 - AnVIL_CCDG_Broad_NP_Epilepsy_AUSAUS_EPIL_BA_MDS_GSA-MD
# 269 - AnVIL_CCDG_Broad_NP_Epilepsy_AUSALF_HMB_IRB_GSRS_WES
# 270 - AnVIL_CCDG_WashU_CVD_EOCAD_BioVu_WGS
# 271 - AnVIL_CCDG_Broad_NP_Epilepsy_DEUUKB_HMB_NPU_MDS_WES
# 272 - anvil_ccdg_broad_ai_ibd_daly_rioux_igenomed_wes
# 273 - AnVIL_CMG_Broad_Blood_Gazda_WES
# 274 - anvil_ccdg_broad_ai_ibd_daly_mcgovern_niddk_wes
# 275 - AnVIL_CCDG_Broad_NP_Epilepsy_FINKPH_EPIL_MDS_GSA-MD
# 276 - AnVIL_CCDG_Broad_NP_Epilepsy_AUSAUS_EP_BA_CN_ID_MDS_GSA-MD
# 277 - AnVIL_CCDG_Broad_NP_Epilepsy_ITAUBG_DS-EPI-NPU-MDS_GSA-MD
# 278 - AnVIL_CCDG_Broad_NP_Epilepsy_CYPCYP_HMB-NPU-MDS_GSA-MD
# 279 - AnVIL_NIMH_Broad_WGSPD1_McCarroll_Escamilla_DS_WGS
# 280 - AnVIL_CCDG_NYGC_NP_Autism_CAG_DS_WGS
# 281 - AnVIL_CCDG_Broad_NP_Epilepsy_TWNCGM_HMB-NPU-ADULTS_GSA-MD
# 282 - AnVIL_CCDG_Broad_NP_Epilepsy_CYPCYP_HMB_NPU_MDS_WES
# 283 - ANVIL_CMG_Yale_GRU
# 284 - AnVIL_CCDG_Broad_CVD_AF_GAPP_DS-MDS_Arrays
# 285 - AnVIL_ccdg_asc_ndd_daly_talkowski_palotie_asd_exome
# 286 - AnVIL_CCDG_Broad_CVD_AFib_Intermountain_WGS
# 287 - AnVIL_ccdg_asc_ndd_daly_talkowski_kolevzon_asd_exome
# 288 - AnVIL_NIMH_Broad_WGSPD1_McCarroll_Pato_GRU_10XLRGenomes
# 289 - AnVIL_CCDG_Broad_NP_Epilepsy_AUSAUS_EP_BA_CN_ID_MDS_WES
# 290 - AnVIL_CCDG_Broad_NP_Epilepsy_USAFEB_GRU_WES
# 291 - AnVIL_ccdg_asc_ndd_daly_talkowski_CDCSEED_asd_exome
# 292 - AnVIL_CCDG_Broad_CVD_AF_Olesen_Arrays
# 293 - AnVIL_CMG_Broad_Muscle_Beggs_WGS
# 294 - AnVIL_CSER_NYCKIDSSEQ_HMB
# 295 - AnVIL_ccdg_asc_ndd_daly_talkowski_hertz-picciotto_asd_exome
# 296 - AnVIL_CCDG_Broad_NP_Epilepsy_JPNRKI_DS_NPD_IRB_NPU_GSA-MD
# 297 - AnVIL_CCDG_Broad_NP_Epilepsy_AUSAUS_EPIL_BA_MDS_WES
# 298 - AnVIL_CMG_Broad_Orphan_Manton_WES
# 299 - anvil_ccdg_broad_ai_ibd_daly_chung_gider_gsa
# 300 - AnVIL_CMG_BaylorHopkins_HMB-IRB-NPU_WES
# 301 - AnVIL_CCDG_Broad_NP_Epilepsy_TWNCGM_HMB-NPU-ADULTS_WES
# 302 - AnVIL_CCDG_Broad_NP_Epilepsy_CANCAL_GSA-MD
# 303 - AnVIL_CCDG_Broad_NP_Epilepsy_USAUPN_Rader_GRU_WES
# 304 - AnVIL_CCDG_Broad_NP_Epilepsy_USALCH_HMB_MDS_GSA-MD
# 305 - AnVIL_CSER_UW_DCC
# 306 - AnVIL_CCDG_Broad_NP_Epilepsy_USANCH_DS_NEURO_MDS_WES
# 307 - AnVIL_CMG_Broad_Stillbirth_Wilkins-Haug_WES
# 308 - AnVIL_CCDG_Broad_NP_Epilepsy_USAMGH_HMB_MDS_WES
# 309 - AnVIL_CCDG_Baylor_CVD_Ventura_Presto_GRU-IRB_WGS
# 310 - AnVIL_eMERGE_GWAS
# 311 - ANVIL_CMG_YALE_DS-MC
# 312 - AnVIL_CCDG_Baylor_CVD_HemStroke_GERFHS_HMB_WGS
# 313 - AnVIL_CCDG_Broad_NP_Epilepsy_HKGHKK_HMB_MDS_GSA-MD
# 314 - anvil_ccdg_broad_ai_ibd_daly_mcgovern_share_wes
# 315 - AnVIL_CCDG_NYGC_NP_Autism_TASC_WGS
# 316 - AnVIL_CCDG_WashU_CVD_EOCAD_Emory_WGS
# 317 - AnVIL_CCDG_Broad_NP_Epilepsy_AUSAUS_EPI_BA_ID_MDS_GSA-MD
# 318 - AnVIL_CCDG_Broad_NP_Epilepsy_CANCAL_GRU_WES
# 319 - ANVIL_CMG_BROAD_BRAIN_WALSH_WGS
# 320 - AnVIL_CCDG_Broad_NP_Epilepsy_USACRW_DS_EP_MDS_WES
# 321 - anvil_ccdg_broad_ai_ibd_daly_xavier_share_wes
# 322 - AnVIL_CCDG_Broad_NP_Epilepsy_KENKIL_GRU_WES
# 323 - anvil_ccdg_broad_ai_ibd_daly_moayyedi_imagine_wes
# 324 - anvil_ccdg_broad_ai_ibd_daly_rioux_igenomed_gsa
# 325 - AnVIL_CCDG_Broad_NP_Epilepsy_GHAKNT_GRU_GSA-MD
# 326 - AnVIL_CCDG_NYGC_NP_Autism_SEARCHLIGHT_DS_WGS
# 327 - AnVIL_CCDG_Broad_CVD_AFib_UCSF_WGS
# 328 - AnVIL_CCDG_Broad_NP_Epilepsy_USAEGP_GRU_WES
# 329 - AnVIL_CMG_Broad_Brain_Engle_WGS
# 330 - AnVIL_CCDG_Baylor_CVD_TexGen_DS_WGS
# 331 - AnVIL_CCDG_Broad_AI_IBD_McCauley_WGS
# 332 - AnVIL_CCDG_Broad_CVD_AF_TMDU_Cases_Arrays
# 333 - AnVIL_ccdg_asc_ndd_daly_talkowski_pericak-vance_asd_exome_
# 334 - AnVIL_ccdg_asc_ndd_daly_talkowski_weiss_asd_exome
# 335 - anvil_ccdg_broad_ai_ibd_daly_lira_share_wes
# 336 - AnVIL_CMG_Broad_Heart_PCGC-Tristani_WGS
# 337 - AnVIL_ccdg_asc_ndd_daly_talkowski_pericak-vance_asd_wgs
# 338 - anvil_ccdg_broad_daly_igsr_1kg_twist_wes
# 339 - AnVIL_CMG_Broad_Orphan_Lerner-Ellis_WGS
# 340 - AnVIL_CCDG_Broad_AI_IBD_Kugathasan_WGS
# 341 - anvil_ccdg_broad_ai_ibd_daly_alm_gmc_gsa
# 342 - AnVIL_CCDG_Broad_CVD_AF_BioVU_HMB_GSO_Arrays
# 343 - AnVIL_CCDG_NYGC_NP_Autism_ACE2_GRU-MDS_WGS
# 344 - AnVIL_CMG_Broad_Kidney_Pollak_WES
# 345 - anvil_ccdg_broad_ai_ibd_daly_bernstein_gsa
# 346 - anvil_ccdg_broad_ai_ibd_daly_silverberg_niddk_gsa
# 347 - AnVIL_CCDG_Baylor_CVD_HemStroke_GOCHA_DS_WGS
# 348 - AnVIL_CCDG_Broad_NP_Epilepsy_USACCH_DS_NEURO_MDS_GSA-MD
# 349 - AnVIL_CCDG_Broad_NP_Epilepsy_USACRW_DS_SEIZD_WES
# 350 - AnVIL_CCDG_Broad_NP_Epilepsy_USACCF_HMB-MDS_GSA-MD
# 351 - AnVIL_CSER_SouthSeq_GRU
# 352 - AnVIL_GTEx_V9_hg38
# 353 - AnVIL_CCDG_WashU_CVD_MultiEthnic_WGS
# 354 - AnVIL_CCDG_Broad_CVD_AF_Figtree_BioHeart_WES
# 355 - AnVIL_CMG_Yale_HMB
# 356 - AnVIL_CMG_Broad_Orphan_Scott_WES
# 357 - AnVIL_CCDG_Broad_NP_Epilepsy_USAMON_GRU_NPU_WES
# 358 - ANVIL_CCDG_Broad_CVD_EOCAD_PROMIS_ARRAY
# 359 - AnVIL_CCDG_Broad_NP_Epilepsy_ZAFAGN_DS-EPI-COMO-MDS_WES
# 360 - AnVIL_CCDG_Baylor_CVD_EOCAD_BioMe_WGS
# 361 - anvil_nhgri_broad_ibd_daly_turner_wes
# 362 - AnVIL_ccdg_asc_ndd_daly_talkowski_goethe_asd_exome
# 363 - AnVIL_CMG_Broad_Muscle_KNC_WES
# 364 - AnVIL_CCDG_Broad_NP_Epilepsy_HRVUZG_HMB_MDS_WES
# 365 - AnVIL_CMG_Broad_Heart_Seidman_WES
# 366 - AnVIL_CMG_Broad_Muscle_INMR-Cooper_WES
# 367 - AnVIL_CCDG_Broad_NP_Epilepsy_CHEUBB_HMB-IRB-MDS_GSA-MD
# 368 - AnVIL_NIMH_Broad_ConvergentNeuro_McCarroll_Eggan_CIRM_GRU_WGS
# 369 - AnVIL_CCDG_Broad_NP_Epilepsy_ITAIGI_GRU_GSA-MD
# 370 - AnVIL_CSER_ClinSeq_GRU
# 371 - AnVIL_CCDG_Broad_CVD_AF_Olesen_WES
# 372 - AnVIL_CCDG_Broad_NP_Epilepsy_AUTMUV_DS_NS_NPU_ADLT_GSA-MD
# 373 - AnVIL_CCDG_NYGC_NP_Alz_WHICAP_WGS
# 374 - AnVIL_CCDG_TOPMed_WashU_CVD_Afib_BioVu_WGS
# 375 - anvil_ccdg_broad_ai_ibd_daly_xavier_prism_wes
# 376 - AnVIL_CCDG_WashU_CVD-NP-AI_Controls_VCControls_WGS
# 377 - AnVIL_CMG_Broad_Heart_Seidman_WGS
# 378 - AnVIL_ccdg_asc_ndd_daly_talkowski_mcpartland_asd_exome
# 379 - AnVIL_CCDG_WashU_CVD_Corogene_WGS
# 380 - AnVIL_CCDG_NYGC_NP_Autism_HMCA_WGS
# 381 - AnVIL_CMG_Broad_Muscle_Bonnemann_WGS
# 382 - AnVIL_ccdg_asc_ndd_daly_talkowski_hertz-picciotto_asd_wgs
# 383 - AnVIL_CCDG_Broad_NP_Epilepsy_USAMSS_DS_EP_NEURO_MDS_WES
# 384 - AnVIL_ccdg_asc_ndd_daly_talkowski_persico_asd_exome
# 385 - AnVIL_CCDG_Broad_CVD_EOCAD_PROMIS_WGS
# 386 - AnVIL_CCDG_Broad_CVD_AF_PEGASUS_HMB
# 387 - AnVIL_CCDG_Broad_NP_Epilepsy_JPNFKA_GRU_WES
# 388 - AnVIL_CCDG_Baylor_CVD_HHRC_Brownsville_GRU_WGS
# 389 - AnVIL_CCDG_Broad_NP_Epilepsy_USAMON_GRU_NPU_GSA-MD
# 390 - AnVIL_CCDG_Broad_NP_Epilepsy_TURBZU_GRU_GSA-MD
# 391 - AnVIL_ccdg_asc_ndd_daly_talkowski_brusco_asd_exome
# 392 - AnVIL_CCDG_NYGC_NP_Autism_GASD_GRU_WGS
# 393 - AnVIL_CCDG_Broad_NP_Epilepsy_USAVAN_HMB-GSO_GSA-MD
# 394 - anvil_ccdg_broad_ai_ibd_daly_hyams_protect_wes
# 395 - AnVIL_CCDG_Broad_CVD_AF_Darbar_UIC_Cases_WES
# 396 - AnVIL_NIMH_Broad_WGSPD1_McCarroll_Braff_DS_WGS
# 397 - AnVIL_CCDG_TOPMed_WashU_CVD_Afib_BioMe_WGS
# 398 - AnVIL_CCDG_Broad_NP_Epilepsy_LEBABM_DS_Epilepsy_GSA-MD
# 399 - AnVIL_CCDG_Broad_CVD_AFib_Vanderbilt-Ablation_WGS
# 400 - AnVIL_CCDG_Broad_AI_IBD_Brant_HMB_WGS
# 401 - AnVIL_CCDG_WashU_CVD_WHI_WGS
# 402 - AnVIL_CMG_Broad_Muscle_Bonnemann_WES
# 403 - AnVIL_NIMH_Broad_ConvergentNeuro_McCarroll_Eggan_Finkel_SMA_DS_WGS
# 404 - AnVIL_CCDG_Broad_NP_Epilepsy_BELULB_DS-EP-NPU_GSA-MD
# 405 - AnVIL_ccdg_asc_ndd_daly_talkowski_parellada_asd_exome
# 406 - AnVIL_CCDG_Broad_NP_Epilepsy_LTUUHK_HMB_NPU_MDS_GSA-MD
# 407 - AnVIL_ccdg_asc_ndd_daly_talkowski_IBIS_asd_exome
# 408 - AnVIL_CCDG_Broad_CVD_EOCAD_PartnersBiobank_HMB_Arrays
# 409 - AnVIL_CCDG_Broad_CVD_PROMIS_GRU_WES
# 410 - AnVIL_NIMH_Broad_WGSPD1_McCarroll_Braff_DS_10XLRGenomes
# 411 - AnVIL_PAGE_SoL_HMB_WGS
# 412 - AnVIL_CMG_Broad_Orphan_Manton_WGS
# 413 - AnVIL_CMG_Broad_Brain_Sherr_WES
# 414 - ANVIL_CMG_UWASH_DS-BAV-IRB-PUB-RD
# 415 - anvil_ccdg_broad_ai_ibd_daly_chen_wes
# 416 - AnVIL_CCDG_Broad_NP_Epilepsy_USACRW_DS_EP_MDS_GSA-MD
# 417 - AnVIL_CCDG_Broad_NP_Epilepsy_BELATW_GRU_GSA-MD
# 418 - AnVIL_CCDG_Broad_NP_Epilepsy_NZLUTO_EPIL_BC_ID_MDS_WES
# 419 - AnVIL_ccdg_asc_ndd_daly_talkowski_mayo_asd_exome
# 420 - AnVIL_CCDG_Broad_NP_Epilepsy_USAMON_GRU_WES
# 421 - anvil_ccdg_broad_ai_ibd_daly_kastner_fmf_gsa
# 422 - AnVIL_CCDG_Broad_NP_Epilepsy_TURIBU_DS_NEURO_AD_NPU_GSA-MD
# 423 - AnVIL_GTEx_V7_hg19
# 424 - AnVIL_CCDG_Broad_NP_Epilepsy_ZAFAGN_DS-EPI-COMO-MDS_GSA-MD
# 425 - AnVIL_CCDG_Broad_NP_Epilepsy_GBRUNL_EP_ETIOLOGY_MDS_WES
# 426 - AnVIL_CCDG_Broad_NP_Epilepsy_DEUUGS_DS_EP_MDS_GSA-MD
# 427 - AnVIL_CCDG_Broad_CVD_Stroke_BRAVE_WGS
# 428 - AnVIL_CCDG_Broad_NP_Epilepsy_KENKIL_GRU_GSA-MD
# 429 - AnVIL_CCDG_Broad_NP_Epilepsy_USAFEB_GRU_GSA-MD
# 430 - AnVIL_CCDG_WashU_CVD_EOCAD_Emerge_WGS
# 431 - AnVIL_CMG_Yale_HMB-GSO
# 432 - AnVIL_CCDG_Broad_NP_Epilepsy_USACCF_HMB-MDS_WES
# 433 - AnVIL_ccdg_asc_ndd_daly_talkowski_minshew_asd_exome
# 434 - AnVIL_CMG_Broad_Blood_Fleming_WES
# 435 - AnVIL_CCDG_WashU_CVD_EOCAD_Duke_WGS
# 436 - anvil_ccdg_asc_ndd_daly_talkowski_cdcseed_asd_gsa-md
# 437 - AnVIL_CCDG_Broad_CVD_AF_Marcus_UCSF_WES
# 438 - ANVIL_CMG_Broad_Orphan_Jueppner_WES
# 439 - AnVIL_NIMH_Broad_ConvergentNeuro_McCarroll_Eggan_CIRM_GRU_VillageData
# 440 - AnVIL_CCDG_Broad_CVD_AF_Ellinor_MGH_Arrays
# 441 - AnVIL_CCDG_Broad_NP_Epilepsy_GBRUCL_DS_EARET_MDS_WES
# 442 - anvil_ccdg_broad_ai_ibd_daly_franchimont_wes
# 443 - AnVIL_CCDG_Broad_CVD_AF_GAPP_DS-MDS_WES
# 444 - AnVIL_CCDG_Broad_CVD_EOCAD_PartnersBiobank_HMB_WES
# 445 - AnVIL_CMG_Broad_Muscle_Ravenscroft_WES
# 446 - AnVIL_CCDG_WashU_CVD_EOCAD_Cleveland_WGS
# 447 - AnVIL_CCDG_NYGC_NP_Autism_SPARK_GRU_WGS
# 448 - AnVIL_GTEx_public_data
# 449 - AnVIL_CCDG_Broad_CVD_AFib_Duke_WGS
# 450 - AnVIL_CCDG_Broad_NP_Epilepsy_USAMON_GRU_GSRS_WES
# 451 - AnVIL_CCDG_Broad_NP_Epilepsy_USAUPN_CHOP_GRU_GSA-MD
# 452 - AnVIL_CCDG_Broad_NP_Epilepsy_USAVANcontrols_HMB-GSO_WES
# 453 - AnVIL_GTEx_BCM_GRU_CoRSIVs
# 454 - AnVIL_CCDG_Broad_NP_Epilepsy_USAVAN_HMB-GSO_WES
# 455 - AnVIL_CMG_Broad_Orphan_VCGS-White_WGS
# 456 - AnVIL_CMG_Broad_Orphan_Lerner-Ellis_WES
# 457 - AnVIL_CCDG_TOPMed_WashU_CVD_Afib_Penn_WGS
# 458 - AnVIL_CCDG_NYGC_NP_Autism_AGRE_WGS
# 459 - AnVIL_CCDG_NYGC_NP_Autism_AFS_DS_WGS
# 460 - AnVIL_CMG_Broad_Muscle_Myoseq_WGS
# 461 - anvil_ccdg_broad_ai_ibd_daly_chen_gsa
# 462 - anvil_ccdg_broad_ai_ibd_daly_moayyedi_imagine_gsa
# 463 - AnVIL_CCDG_Baylor_CVD_ARIC
# 464 - AnVIL_CCDG_TOPMed_WashU_CVD_Afib_Duke_WGS
# 465 - anvil_ccdg_broad_ai_ibd_daly_burnstein_gsa
# 466 - AnVIL_CCDG_Baylor_CVD_AFib_VAFAR_HMB-IRB_WGS
# 467 - AnVIL_CMG_Broad_Muscle_Kang_WGS
# 468 - anvil_ccdg_broad_ai_ibd_daly_mccauley_gsa
# 469 - AnVIL_CCDG_Baylor_CVD_AFib_Groningen_WGS
# 470 - AnVIL_CCDG_Broad_NP_Epilepsy_AUSALF_HMB_IRB_GSRS_GSA-MD
# 471 - AnVIL_ccdg_asc_ndd_daly_talkowski_schloesser_asd_exome
# 472 - AnVIL_CCDG_Broad_NP_Epilepsy_IRLRCI_GRU-IRB_GSA-MD
# 473 - anvil_ccdg_broad_ai_ibd_daly_burnstein_utsw_wes
# 474 - anvil_ccdg_broad_ai_ibd_daly_stampfer_wes
# 475 - AnVIL_CMG_Broad_Eye_Pierce_WGS
# 476 - AnVIL_CCDG_Broad_NP_Epilepsy_USAHEP_GRU_GSA-MD
# 477 - AnVIL_CCDG_Broad_NP_Epilepsy_AUTMUV_DS_NS_NPU_ADLT_WES
# 478 - AnVIL_CCDG_Broad_NP_Epilepsy_CZEMTH_GRU_GSA-MD
# 479 - AnVIL_CCDG_Broad_NP_Epilepsy_USAHEP_GRU_WES
# 480 - AnVIL_CCDG_Broad_MI_UnivUtah_DS_CVD_WES
# 481 - ANVIL_CMG_BROAD_BRAIN_SHERR_WGS
# 482 - AnVIL_CCDG_Broad_NP_Epilepsy_ITAICB_HMB_NPU_MDS_WES
# 483 - anvil_ccdg_broad_ai_ibd_daly_rioux_niddk_gsa
# 484 - AnVIL_GTEx_V8_hg38
# 485 - AnVIL_CCDG_Baylor_CVD_HemStroke_Regards_DS_WGS
# Copying file://./AnVILCatalogWorkspacesPublicMetadata-2022-03-09.csv [Content-Type=text/csv]...
# / [1 files][ 91.0 KiB/ 91.0 KiB]
# Operation completed over 1 objects/91.0 KiB.

# %%
pp.pprint(getEntityCounts('AnVIL_CCDG_Broad_CVD_AFib_AFLMU_WGS'))
# Out:
# {   'discoveryCount': 0,
#     'familyCount': 0,
#     'participantCount': 248,
#     'sampleCount': 248,
#     'subjectCount': 0}

# %%
pp.pprint( FAPI.list_entity_types(CATALOG_WORKSPACE_NAMESPACE, 'AnVIL_CCDG_Broad_CVD_AFib_AFLMU_WGS').json())
# Out:
# {   'participant': {   'attributeNames': [   'collaborator_participant_id',
#                                              'gender',
#                                              'participant'],
#                        'count': 248,
#                        'idName': 'participant_id'},
#     'qc_result_sample': {   'attributeNames': [   'cram',
#                                                   'freemix',
#                                                   'mean_coverage',
#                                                   'median_absolute_deviation',
#                                                   'median_insert_size',
#                                                   'pct_10x',
#                                                   'pct_20x',
#                                                   'pct_30x',
#                                                   'pct_chimeras',
#                                                   'percent_duplication',
#                                                   'q20_bases',
#                                                   'qc_result_sample',
#                                                   'qc_status',
#                                                   'read1_pf_mismatch_rate',
#                                                   'read2_pf_mismatch_rate'],
#                             'count': 248,
#                             'idName': 'qc_result_sample_id'},
#     'sample': {   'attributeNames': [   '10x_rate',
#                                         '20x_rate',
#                                         'adapter_rate',
#                                         'chimera_rate',
#                                         'collaborator_participant_id',
#                                         'collaborator_sample_id',
#                                         'contamination_rate',
#                                         'crai_path',
#                                         'cram_path',
#                                         'data_type',
#                                         'exc_baseq_rate',
#                                         'exc_dupe_rate',
#                                         'exc_mapq_rate',
#                                         'exc_overlap_rate',
#                                         'exc_total_rate',
#                                         'exc_unpaired_rate',
#                                         'genome_territory',
#                                         'lc_set',
#                                         'library-1_estimated_library_size',
#                                         'library-1_mean_insert_size',
#                                         'library-1_name',
#                                         'library-1_pct_exc_dupe',
#                                         'library-1_percent_duplication',
#                                         'lod_expected_sample',
#                                         'md5_path',
#                                         'mean_coverage',
#                                         'mean_read_length',
#                                         'participant',
#                                         'pdo',
#                                         'pf_aligned_bases',
#                                         'pf_hq_aligned_bases',
#                                         'pf_hq_aligned_q20_bases',
#                                         'pf_hq_aligned_reads',
#                                         'pf_mismatch_rate',
#                                         'pf_noise_reads',
#                                         'pf_reads',
#                                         'pf_reads_aligned',
#                                         'pf_reads_aligned_rate',
#                                         'pf_reads_rate',
#                                         'project',
#                                         'read_group_count',
#                                         'reads_aligned_in_pairs',
#                                         'reads_aligned_in_pairs_rate',
#                                         'reference_sequence_name',
#                                         'release_date',
#                                         'research_project',
#                                         'root_sample_id',
#                                         'sample_type',
#                                         'total_reads',
#                                         'version'],
#                   'count': 248,
#                   'idName': 'sample_id'},
#     'sample_set': {   'attributeNames': ['release_date', 'samples'],
#                       'count': 1,
#                       'idName': 'sample_set_id'}}
