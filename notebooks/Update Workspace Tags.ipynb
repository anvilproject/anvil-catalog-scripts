# %%
"""
Update tags from the given spreadsheet to add a structure like:

tag:tags": {
          "itemsType": "AttributeValue",
          "items": [
            "dbGaP:phs001584",
            "consortium:eMERGE",
            "consent_code:HMB-MDS"
          ]
        },

Tag Types:
dbGaP: None | phs001234
consortium: string
consent_code: string
"""
## Imports
import datetime
import firecloud.api as FAPI
import json
import os
import pandas as pd
import pprint
import re
import requests



print(FAPI.whoami())
pp = pprint.PrettyPrinter(indent=4)

BILLING_PROJECT_ID = os.environ['WORKSPACE_NAMESPACE']
WORKSPACE = os.environ['WORKSPACE_NAME']
WORKSPACE_BUCKET = os.environ['WORKSPACE_BUCKET']

CATALOG_WORKSPACE_NAMESPACE = "anvil-datastorage"
API_ROOT = "https://api.firecloud.org/api"
ANVIL_DATA_STORAGE = "anvil-datastorage"

def getDefaultAccessToken():
    result = !gcloud auth application-default print-access-token
    return result[0]


ACCESS_TOKEN = getDefaultAccessToken()

print(BILLING_PROJECT_ID)
print(WORKSPACE)

print("Copy files:")
# print(WORKSPACE_BUCKET)
# !gsutil cp $WORKSPACE_BUCKET/notebooks/AnVILCatalogWorkspacesPublicMetadata-2022-03-10.csv  .
print("List all files:")
# !ls 

## Read in tags list
metadata = pd.read_csv('AnVILCatalogWorkspacesPublicMetadata-2022-03-10.csv')
metadata = metadata[["name","consortium", "phsId"]]
metadata.set_index("name", inplace=True)


def getTagsURL(namespace,workspace):
    return  API_ROOT+"/workspaces/"+ namespace + "/" + workspace + "/tags"

def getAPIHeaders():
    headers = {
        'accept': 'application/json',
        'Authorization' : 'Bearer '+ACCESS_TOKEN
    }
    return headers

# Return the list of tags for a given workspace    
def getWorkspaceTags(namespace,workspace):
    url = getTagsURL(namespace,workspace)
    headers = getAPIHeaders()
    r = requests.get(url, headers = headers)
    return r.json()

# Replaces the set the tags on a workspace to the given list of tags
def setWorkspaceTags(namespace,workspace,tags):
    if not isinstance(tags,list):
        raise Exception('Tags must be a list')
        
#     if len(tags) > 15:
#         raise Exception('Limit to setting only 10 tags for now.')
        
    url = getTagsURL(namespace,workspace)
    headers = getAPIHeaders()
    resp = requests.put(url, json=tags, headers=headers)
    print(resp.status_code)

def backupWorkspace(w):
   
    # Create the filename
    name = w['workspace']['name']
    timestampStr = datetime.datetime.now().isoformat()
    fileName = name+'_'+timestampStr+'.json'
    
    # Save the to the local cloud environment
    with open(fileName, 'w') as fp:
        json.dump(w, fp,  indent=4)
        
    # Copy the file to the workspace bucket
    # !gsutil cp ./$fileName $WORKSPACE_BUCKET/backups/

    
def modifyNextTags(tags, tag):
    if tag.startswith("Consortium"):
        key = "Consortium"
    elif tag.startswith("dbGaP"):
        key = "dbGap"
    else:
        raise Exception("Unknonw tag.." + tag)
    
    # Remove all tags of type key
    nextTags = list(filter(lambda el: not re.search(key, el, re.IGNORECASE),tags))
    
    # Add back the current one
    nextTags.append(tag)
    return nextTags

## Filter out workspaces without write access
workspaces = FAPI.list_workspaces().json()

reader = set()
writer = set()
for w in workspaces:
    name = w['workspace']['name']
    if w['accessLevel'] == "READER":
        reader.add(name)
    if w['accessLevel'] == "WRITER" or w['accessLevel'] == "OWNER":
        writer.add(name)
# Out:
# pet-117272931645288568532@terra-e36fcccd.iam.gserviceaccount.com
nVIL_NIMH_Broad_ConvergentNeuro_McCarroll_Eggan_Finkel_SMA_DS_WGS_2022-03-10T08:01:20.917198.json
#  AnVIL_NIMH_Broad_WGSPD1_McCarroll_Braff_DS_10XLRGenomes_2022-03-10T08:02:19.626244.json
#  AnVIL_NIMH_Broad_WGSPD1_McCarroll_Braff_DS_WGS_2022-03-10T08:00:20.101089.json
#  AnVIL_NIMH_Broad_WGSPD1_McCarroll_Escamilla_DS_WGS_2022-03-10T07:43:49.441104.json
#  AnVIL_NIMH_Broad_WGSPD1_McCarroll_Pato_GRU_10XLRGenomes_2022-03-10T07:45:00.104193.json
#  AnVIL_NIMH_Broad_WGSPD1_McCarroll_Pato_GRU_WGS_2022-03-10T07:32:44.409851.json
#  AnVIL_NIMH_CIRM_FCDI_ConvergentNeuro_McCarroll_Eggan_GRU_Arrays_2022-03-10T07:13:53.306601.json
#  AnVIL_PAGE_BioMe_GRU_WGS_2022-03-10T07:10:26.462193.json
#  AnVIL_PAGE_MEC_GRU_WGS_2022-03-10T07:18:58.382148.json
#  AnVIL_PAGE_SoL_HMB_WGS_2022-03-10T08:02:28.251235.json
#  AnVIL_PAGE_Stanford_Global_Reference_Panel_GRU_WGS_2022-03-10T07:11:38.488302.json
#  AnVIL_PAGE_WHI_HMB-IRB_WGS_2022-03-10T07:37:29.529495.json
#  AnVIL_T2T_2022-03-10T07:26:42.334333.json
#  anvil_workspaces_tags_220211.tsv
#  attributes_for_AnVIL_workspaces_220204.csv
#  attributes_for_AnVIL_workspaces_update_210217.csv
# 'Catalog Spreadsheet vs API Diff Report.ipynb'
# 'Combine and Trim DaveUsing and TagSheet.ipynb'
# 'Create Dataset Catalog Report.ipynb'
# 'TCGA_LAML_hg38_OpenAccess_GDCDR-12-0_DATA_03-Mar-2022 (06:56:49.305641).json'
# 'TCGA_LAML_hg38_OpenAccess_GDCDR-12-0_DATA_03-Mar-2022 (06:58:04.398875).json'
#  TCGA_LAML_hg38_OpenAccess_GDCDR-12-0_DATA_2022-03-03T07:03:16.663543.json
#  TCGA_LAML_hg38_OpenAccess_GDCDR-12-0_DATA_2022-03-03T07:05:27.929056.json
#  TCGA_LAML_hg38_OpenAccess_GDCDR-12-0_DATA_2022-03-03T07:06:28.634137.json
# 'Tile DB Playground.ipynb'
# 'Update Workspace Attributes.ipynb'
# 'Update Workspace Tags.ipynb'

# %%
## Update workspace tags
length = 0        
for w in workspaces:
    name = w['workspace']['name']
    if name in writer and name in metadata.index.values:
        length = length+1
        if length <= 410:
            continue 
#         if length > 2:
#             break        
        # Get consortium from tags sheet
        consortium = metadata.at[name,"consortium"]
        dbGaP = metadata.at[name,"phsId"]
        tags = []
        tags.append("Consortium: " + consortium)
        tags.append("dbGaP: " + dbGaP)

        print("##########################")
        backupWorkspace(w)
        currentTags = getWorkspaceTags(ANVIL_DATA_STORAGE,name)
        nextTags = currentTags.copy()
        for tag in tags:
            nextTags = modifyNextTags(nextTags,tag)

        print(name)
        # Update the workspace's tags
        setWorkspaceTags(ANVIL_DATA_STORAGE,name, nextTags)
# Out:
# ##########################
# Copying file://./AnVIL_PAGE_SoL_HMB_WGS_2022-03-10T08:16:07.966827.json [Content-Type=application/json]...
# / [1 files][  3.4 KiB/  3.4 KiB]
# Operation completed over 1 objects/3.4 KiB.
# AnVIL_PAGE_SoL_HMB_WGS
# 200
# ##########################
# Copying file://./AnVIL_CMG_Broad_Orphan_Manton_WGS_2022-03-10T08:16:17.337221.json [Content-Type=application/json]...
# / [1 files][  4.6 KiB/  4.6 KiB]
# Operation completed over 1 objects/4.6 KiB.
# AnVIL_CMG_Broad_Orphan_Manton_WGS
# 200
# ##########################
# Copying file://./AnVIL_CMG_Broad_Brain_Sherr_WES_2022-03-10T08:16:26.221108.json [Content-Type=application/json]...
# / [1 files][  3.4 KiB/  3.4 KiB]
# Operation completed over 1 objects/3.4 KiB.
# AnVIL_CMG_Broad_Brain_Sherr_WES
# 200
# ##########################
# Copying file://./ANVIL_CMG_UWASH_DS-BAV-IRB-PUB-RD_2022-03-10T08:16:34.607953.json [Content-Type=application/json]...
# / [1 files][  3.8 KiB/  3.8 KiB]
# Operation completed over 1 objects/3.8 KiB.
# ANVIL_CMG_UWASH_DS-BAV-IRB-PUB-RD
# 200
# ##########################
# Copying file://./anvil_ccdg_broad_ai_ibd_daly_chen_wes_2022-03-10T08:16:42.182848.json [Content-Type=application/json]...
# / [1 files][  4.4 KiB/  4.4 KiB]
# Operation completed over 1 objects/4.4 KiB.
# anvil_ccdg_broad_ai_ibd_daly_chen_wes
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_USACRW_DS_EP_MDS_GSA-MD_2022-03-10T08:16:50.134186.json [Content-Type=application/json]...
# / [1 files][  3.8 KiB/  3.8 KiB]
# Operation completed over 1 objects/3.8 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_USACRW_DS_EP_MDS_GSA-MD
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_BELATW_GRU_GSA-MD_2022-03-10T08:16:58.142877.json [Content-Type=application/json]...
# / [1 files][  4.0 KiB/  4.0 KiB]
# Operation completed over 1 objects/4.0 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_BELATW_GRU_GSA-MD
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_NZLUTO_EPIL_BC_ID_MDS_WES_2022-03-10T08:17:06.259656.json [Content-Type=application/json]...
# / [1 files][  4.5 KiB/  4.5 KiB]
# Operation completed over 1 objects/4.5 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_NZLUTO_EPIL_BC_ID_MDS_WES
# 200
# ##########################
# Copying file://./AnVIL_ccdg_asc_ndd_daly_talkowski_mayo_asd_exome_2022-03-10T08:17:14.387756.json [Content-Type=application/json]...
# / [1 files][  4.5 KiB/  4.5 KiB]
# Operation completed over 1 objects/4.5 KiB.
# AnVIL_ccdg_asc_ndd_daly_talkowski_mayo_asd_exome
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_USAMON_GRU_WES_2022-03-10T08:17:23.381076.json [Content-Type=application/json]...
# / [1 files][  4.4 KiB/  4.4 KiB]
# Operation completed over 1 objects/4.4 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_USAMON_GRU_WES
# 200
# ##########################
# Copying file://./anvil_ccdg_broad_ai_ibd_daly_kastner_fmf_gsa_2022-03-10T08:17:31.792238.json [Content-Type=application/json]...
# / [1 files][  4.1 KiB/  4.1 KiB]
# Operation completed over 1 objects/4.1 KiB.
# anvil_ccdg_broad_ai_ibd_daly_kastner_fmf_gsa
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_TURIBU_DS_NEURO_AD_NPU_GSA-MD_2022-03-10T08:17:36.795735.json [Content-Type=application/json]...
# / [1 files][  4.0 KiB/  4.0 KiB]
# Operation completed over 1 objects/4.0 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_TURIBU_DS_NEURO_AD_NPU_GSA-MD
# 200
# ##########################
# Copying file://./AnVIL_GTEx_V7_hg19_2022-03-10T08:17:42.057301.json [Content-Type=application/json]...
# / [1 files][  7.1 KiB/  7.1 KiB]
# Operation completed over 1 objects/7.1 KiB.
# AnVIL_GTEx_V7_hg19
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_ZAFAGN_DS-EPI-COMO-MDS_GSA-MD_2022-03-10T08:17:46.928932.json [Content-Type=application/json]...
# / [1 files][  3.7 KiB/  3.7 KiB]
# Operation completed over 1 objects/3.7 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_ZAFAGN_DS-EPI-COMO-MDS_GSA-MD
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_GBRUNL_EP_ETIOLOGY_MDS_WES_2022-03-10T08:17:51.831913.json [Content-Type=application/json]...
# / [1 files][  4.4 KiB/  4.4 KiB]
# Operation completed over 1 objects/4.4 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_GBRUNL_EP_ETIOLOGY_MDS_WES
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_DEUUGS_DS_EP_MDS_GSA-MD_2022-03-10T08:17:56.725030.json [Content-Type=application/json]...
# / [1 files][  3.7 KiB/  3.7 KiB]
# Operation completed over 1 objects/3.7 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_DEUUGS_DS_EP_MDS_GSA-MD
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_CVD_Stroke_BRAVE_WGS_2022-03-10T08:18:01.941862.json [Content-Type=application/json]...
# / [1 files][  5.8 KiB/  5.8 KiB]
# Operation completed over 1 objects/5.8 KiB.
# AnVIL_CCDG_Broad_CVD_Stroke_BRAVE_WGS
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_KENKIL_GRU_GSA-MD_2022-03-10T08:18:06.926278.json [Content-Type=application/json]...
# / [1 files][  3.6 KiB/  3.6 KiB]
# Operation completed over 1 objects/3.6 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_KENKIL_GRU_GSA-MD
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_USAFEB_GRU_GSA-MD_2022-03-10T08:18:11.829365.json [Content-Type=application/json]...
# / [1 files][  3.7 KiB/  3.7 KiB]
# Operation completed over 1 objects/3.7 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_USAFEB_GRU_GSA-MD
# 200
# ##########################
# Copying file://./AnVIL_CCDG_WashU_CVD_EOCAD_Emerge_WGS_2022-03-10T08:18:16.762998.json [Content-Type=application/json]...
# / [1 files][  4.6 KiB/  4.6 KiB]
# Operation completed over 1 objects/4.6 KiB.
# AnVIL_CCDG_WashU_CVD_EOCAD_Emerge_WGS
# 200
# ##########################
# Copying file://./AnVIL_CMG_Yale_HMB-GSO_2022-03-10T08:18:22.324974.json [Content-Type=application/json]...
# / [1 files][  3.6 KiB/  3.6 KiB]
# Operation completed over 1 objects/3.6 KiB.
# AnVIL_CMG_Yale_HMB-GSO
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_USACCF_HMB-MDS_WES_2022-03-10T08:18:27.278711.json [Content-Type=application/json]...
# / [1 files][  4.5 KiB/  4.5 KiB]
# Operation completed over 1 objects/4.5 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_USACCF_HMB-MDS_WES
# 200
# ##########################
# Copying file://./AnVIL_ccdg_asc_ndd_daly_talkowski_minshew_asd_exome_2022-03-10T08:18:32.234461.json [Content-Type=application/json]...
# / [1 files][  4.3 KiB/  4.3 KiB]
# Operation completed over 1 objects/4.3 KiB.
# AnVIL_ccdg_asc_ndd_daly_talkowski_minshew_asd_exome
# 200
# ##########################
# Copying file://./AnVIL_CMG_Broad_Blood_Fleming_WES_2022-03-10T08:18:37.207680.json [Content-Type=application/json]...
# / [1 files][  3.3 KiB/  3.3 KiB]
# Operation completed over 1 objects/3.3 KiB.
# AnVIL_CMG_Broad_Blood_Fleming_WES
# 200
# ##########################
# Copying file://./AnVIL_CCDG_WashU_CVD_EOCAD_Duke_WGS_2022-03-10T08:18:42.369565.json [Content-Type=application/json]...
# / [1 files][  4.8 KiB/  4.8 KiB]
# Operation completed over 1 objects/4.8 KiB.
# AnVIL_CCDG_WashU_CVD_EOCAD_Duke_WGS
# 200
# ##########################
# Copying file://./anvil_ccdg_asc_ndd_daly_talkowski_cdcseed_asd_gsa-md_2022-03-10T08:18:47.866186.json [Content-Type=application/json]...
# / [1 files][  4.2 KiB/  4.2 KiB]
# Operation completed over 1 objects/4.2 KiB.
# anvil_ccdg_asc_ndd_daly_talkowski_cdcseed_asd_gsa-md
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_CVD_AF_Marcus_UCSF_WES_2022-03-10T08:18:52.828135.json [Content-Type=application/json]...
# / [1 files][  3.3 KiB/  3.3 KiB]
# Operation completed over 1 objects/3.3 KiB.
# AnVIL_CCDG_Broad_CVD_AF_Marcus_UCSF_WES
# 200
# ##########################
# Copying file://./ANVIL_CMG_Broad_Orphan_Jueppner_WES_2022-03-10T08:18:57.937649.json [Content-Type=application/json]...
# / [1 files][  3.4 KiB/  3.4 KiB]
# Operation completed over 1 objects/3.4 KiB.
# ANVIL_CMG_Broad_Orphan_Jueppner_WES
# 200
# ##########################
# Copying file://./AnVIL_NIMH_Broad_ConvergentNeuro_McCarroll_Eggan_CIRM_GRU_VillageData_2022-03-10T08:19:02.903855.json [Content-Type=application/json]...
# / [1 files][  5.2 KiB/  5.2 KiB]
# Operation completed over 1 objects/5.2 KiB.
# AnVIL_NIMH_Broad_ConvergentNeuro_McCarroll_Eggan_CIRM_GRU_VillageData
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_CVD_AF_Ellinor_MGH_Arrays_2022-03-10T08:19:07.822872.json [Content-Type=application/json]...
# / [1 files][  3.8 KiB/  3.8 KiB]
# Operation completed over 1 objects/3.8 KiB.
# AnVIL_CCDG_Broad_CVD_AF_Ellinor_MGH_Arrays
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_GBRUCL_DS_EARET_MDS_WES_2022-03-10T08:19:12.819889.json [Content-Type=application/json]...
# / [1 files][  4.4 KiB/  4.4 KiB]
# Operation completed over 1 objects/4.4 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_GBRUCL_DS_EARET_MDS_WES
# 200
# ##########################
# Copying file://./anvil_ccdg_broad_ai_ibd_daly_franchimont_wes_2022-03-10T08:19:17.702001.json [Content-Type=application/json]...
# / [1 files][  4.8 KiB/  4.8 KiB]
# Operation completed over 1 objects/4.8 KiB.
# anvil_ccdg_broad_ai_ibd_daly_franchimont_wes
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_CVD_AF_GAPP_DS-MDS_WES_2022-03-10T08:19:22.618496.json [Content-Type=application/json]...
# / [1 files][  4.3 KiB/  4.3 KiB]
# Operation completed over 1 objects/4.3 KiB.
# AnVIL_CCDG_Broad_CVD_AF_GAPP_DS-MDS_WES
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_CVD_EOCAD_PartnersBiobank_HMB_WES_2022-03-10T08:19:27.567979.json [Content-Type=application/json]...
# / [1 files][  5.6 KiB/  5.6 KiB]
# Operation completed over 1 objects/5.6 KiB.
# AnVIL_CCDG_Broad_CVD_EOCAD_PartnersBiobank_HMB_WES
# 200
# ##########################
# Copying file://./AnVIL_CMG_Broad_Muscle_Ravenscroft_WES_2022-03-10T08:19:32.587831.json [Content-Type=application/json]...
# / [1 files][  4.4 KiB/  4.4 KiB]
# Operation completed over 1 objects/4.4 KiB.
# AnVIL_CMG_Broad_Muscle_Ravenscroft_WES
# 200
# ##########################
# Copying file://./AnVIL_CCDG_WashU_CVD_EOCAD_Cleveland_WGS_2022-03-10T08:19:37.543996.json [Content-Type=application/json]...
# / [1 files][  4.6 KiB/  4.6 KiB]
# Operation completed over 1 objects/4.6 KiB.
# AnVIL_CCDG_WashU_CVD_EOCAD_Cleveland_WGS
# 200
# ##########################
# Copying file://./AnVIL_CCDG_NYGC_NP_Autism_SPARK_GRU_WGS_2022-03-10T08:19:43.102643.json [Content-Type=application/json]...
# / [1 files][  4.2 KiB/  4.2 KiB]
# Operation completed over 1 objects/4.2 KiB.
# AnVIL_CCDG_NYGC_NP_Autism_SPARK_GRU_WGS
# 200
# ##########################
# Copying file://./AnVIL_GTEx_public_data_2022-03-10T08:19:48.664061.json [Content-Type=application/json]...
# / [1 files][  5.9 KiB/  5.9 KiB]
# Operation completed over 1 objects/5.9 KiB.
# AnVIL_GTEx_public_data
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_CVD_AFib_Duke_WGS_2022-03-10T08:19:53.589195.json [Content-Type=application/json]...
# / [1 files][  5.4 KiB/  5.4 KiB]
# Operation completed over 1 objects/5.4 KiB.
# AnVIL_CCDG_Broad_CVD_AFib_Duke_WGS
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_USAMON_GRU_GSRS_WES_2022-03-10T08:19:58.521050.json [Content-Type=application/json]...
# / [1 files][  4.5 KiB/  4.5 KiB]
# Operation completed over 1 objects/4.5 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_USAMON_GRU_GSRS_WES
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_USAUPN_CHOP_GRU_GSA-MD_2022-03-10T08:20:03.576585.json [Content-Type=application/json]...
# / [1 files][  4.5 KiB/  4.5 KiB]
# Operation completed over 1 objects/4.5 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_USAUPN_CHOP_GRU_GSA-MD
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_USAVANcontrols_HMB-GSO_WES_2022-03-10T08:20:08.545327.json [Content-Type=application/json]...
# / [1 files][  4.4 KiB/  4.4 KiB]
# Operation completed over 1 objects/4.4 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_USAVANcontrols_HMB-GSO_WES
# 200
# ##########################
# Copying file://./AnVIL_GTEx_BCM_GRU_CoRSIVs_2022-03-10T08:20:13.519931.json [Content-Type=application/json]...
# / [1 files][  4.0 KiB/  4.0 KiB]
# Operation completed over 1 objects/4.0 KiB.
# AnVIL_GTEx_BCM_GRU_CoRSIVs
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_USAVAN_HMB-GSO_WES_2022-03-10T08:20:18.487515.json [Content-Type=application/json]...
# / [1 files][  4.3 KiB/  4.3 KiB]
# Operation completed over 1 objects/4.3 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_USAVAN_HMB-GSO_WES
# 200
# ##########################
# Copying file://./AnVIL_CMG_Broad_Orphan_VCGS-White_WGS_2022-03-10T08:20:23.404888.json [Content-Type=application/json]...
# / [1 files][  4.6 KiB/  4.6 KiB]
# Operation completed over 1 objects/4.6 KiB.
# AnVIL_CMG_Broad_Orphan_VCGS-White_WGS
# 200
# ##########################
# Copying file://./AnVIL_CMG_Broad_Orphan_Lerner-Ellis_WES_2022-03-10T08:20:28.319474.json [Content-Type=application/json]...
# / [1 files][  3.4 KiB/  3.4 KiB]
# Operation completed over 1 objects/3.4 KiB.
# AnVIL_CMG_Broad_Orphan_Lerner-Ellis_WES
# 200
# ##########################
# Copying file://./AnVIL_CCDG_TOPMed_WashU_CVD_Afib_Penn_WGS_2022-03-10T08:20:33.333354.json [Content-Type=application/json]...
# / [1 files][  3.2 KiB/  3.2 KiB]
# Operation completed over 1 objects/3.2 KiB.
# AnVIL_CCDG_TOPMed_WashU_CVD_Afib_Penn_WGS
# 200
# ##########################
# Copying file://./AnVIL_CCDG_NYGC_NP_Autism_AGRE_WGS_2022-03-10T08:20:38.352465.json [Content-Type=application/json]...
# / [1 files][  4.9 KiB/  4.9 KiB]
# Operation completed over 1 objects/4.9 KiB.
# AnVIL_CCDG_NYGC_NP_Autism_AGRE_WGS
# 200
# ##########################
# Copying file://./AnVIL_CCDG_NYGC_NP_Autism_AFS_DS_WGS_2022-03-10T08:20:43.944949.json [Content-Type=application/json]...
# / [1 files][  3.8 KiB/  3.8 KiB]
# Operation completed over 1 objects/3.8 KiB.
# AnVIL_CCDG_NYGC_NP_Autism_AFS_DS_WGS
# 200
# ##########################
# Copying file://./AnVIL_CMG_Broad_Muscle_Myoseq_WGS_2022-03-10T08:20:49.569299.json [Content-Type=application/json]...
# / [1 files][  3.6 KiB/  3.6 KiB]
# Operation completed over 1 objects/3.6 KiB.
# AnVIL_CMG_Broad_Muscle_Myoseq_WGS
# 200
# ##########################
# Copying file://./anvil_ccdg_broad_ai_ibd_daly_chen_gsa_2022-03-10T08:20:54.624804.json [Content-Type=application/json]...
# / [1 files][  4.0 KiB/  4.0 KiB]
# Operation completed over 1 objects/4.0 KiB.
# anvil_ccdg_broad_ai_ibd_daly_chen_gsa
# 200
# ##########################
# Copying file://./anvil_ccdg_broad_ai_ibd_daly_moayyedi_imagine_gsa_2022-03-10T08:20:59.623305.json [Content-Type=application/json]...
# / [1 files][  3.6 KiB/  3.6 KiB]
# Operation completed over 1 objects/3.6 KiB.
# anvil_ccdg_broad_ai_ibd_daly_moayyedi_imagine_gsa
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Baylor_CVD_ARIC_2022-03-10T08:21:04.609769.json [Content-Type=application/json]...
# / [1 files][  4.2 KiB/  4.2 KiB]
# Operation completed over 1 objects/4.2 KiB.
# AnVIL_CCDG_Baylor_CVD_ARIC
# 200
# ##########################
# Copying file://./AnVIL_CCDG_TOPMed_WashU_CVD_Afib_Duke_WGS_2022-03-10T08:21:10.381694.json [Content-Type=application/json]...
# / [1 files][  3.2 KiB/  3.2 KiB]
# Operation completed over 1 objects/3.2 KiB.
# AnVIL_CCDG_TOPMed_WashU_CVD_Afib_Duke_WGS
# 200
# ##########################
# Copying file://./anvil_ccdg_broad_ai_ibd_daly_burnstein_gsa_2022-03-10T08:21:15.563650.json [Content-Type=application/json]...
# / [1 files][  4.1 KiB/  4.1 KiB]
# Operation completed over 1 objects/4.1 KiB.
# anvil_ccdg_broad_ai_ibd_daly_burnstein_gsa
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Baylor_CVD_AFib_VAFAR_HMB-IRB_WGS_2022-03-10T08:21:20.604770.json [Content-Type=application/json]...
# / [1 files][  3.9 KiB/  3.9 KiB]
# Operation completed over 1 objects/3.9 KiB.
# AnVIL_CCDG_Baylor_CVD_AFib_VAFAR_HMB-IRB_WGS
# 200
# ##########################
# Copying file://./AnVIL_CMG_Broad_Muscle_Kang_WGS_2022-03-10T08:21:26.266880.json [Content-Type=application/json]...
# / [1 files][  4.0 KiB/  4.0 KiB]
# Operation completed over 1 objects/4.0 KiB.
# AnVIL_CMG_Broad_Muscle_Kang_WGS
# 200
# ##########################
# Copying file://./anvil_ccdg_broad_ai_ibd_daly_mccauley_gsa_2022-03-10T08:21:31.157877.json [Content-Type=application/json]...
# / [1 files][  4.0 KiB/  4.0 KiB]
# Operation completed over 1 objects/4.0 KiB.
# anvil_ccdg_broad_ai_ibd_daly_mccauley_gsa
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Baylor_CVD_AFib_Groningen_WGS_2022-03-10T08:21:36.280680.json [Content-Type=application/json]...
# / [1 files][  4.6 KiB/  4.6 KiB]
# Operation completed over 1 objects/4.6 KiB.
# AnVIL_CCDG_Baylor_CVD_AFib_Groningen_WGS
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_AUSALF_HMB_IRB_GSRS_GSA-MD_2022-03-10T08:21:41.852496.json [Content-Type=application/json]...
# / [1 files][  4.0 KiB/  4.0 KiB]
# Operation completed over 1 objects/4.0 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_AUSALF_HMB_IRB_GSRS_GSA-MD
# 200
# ##########################
# Copying file://./AnVIL_ccdg_asc_ndd_daly_talkowski_schloesser_asd_exome_2022-03-10T08:21:46.823509.json [Content-Type=application/json]...
# / [1 files][  3.6 KiB/  3.6 KiB]
# Operation completed over 1 objects/3.6 KiB.
# AnVIL_ccdg_asc_ndd_daly_talkowski_schloesser_asd_exome
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_IRLRCI_GRU-IRB_GSA-MD_2022-03-10T08:21:51.770896.json [Content-Type=application/json]...
# / [1 files][  4.5 KiB/  4.5 KiB]
# Operation completed over 1 objects/4.5 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_IRLRCI_GRU-IRB_GSA-MD
# 200
# ##########################
# Copying file://./anvil_ccdg_broad_ai_ibd_daly_burnstein_utsw_wes_2022-03-10T08:21:56.705469.json [Content-Type=application/json]...
# / [1 files][  3.3 KiB/  3.3 KiB]
# Operation completed over 1 objects/3.3 KiB.
# anvil_ccdg_broad_ai_ibd_daly_burnstein_utsw_wes
# 200
# ##########################
# Copying file://./anvil_ccdg_broad_ai_ibd_daly_stampfer_wes_2022-03-10T08:22:01.680577.json [Content-Type=application/json]...
# / [1 files][  4.3 KiB/  4.3 KiB]
# Operation completed over 1 objects/4.3 KiB.
# anvil_ccdg_broad_ai_ibd_daly_stampfer_wes
# 200
# ##########################
# Copying file://./AnVIL_CMG_Broad_Eye_Pierce_WGS_2022-03-10T08:22:06.796944.json [Content-Type=application/json]...
# / [1 files][  4.6 KiB/  4.6 KiB]
# Operation completed over 1 objects/4.6 KiB.
# AnVIL_CMG_Broad_Eye_Pierce_WGS
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_USAHEP_GRU_GSA-MD_2022-03-10T08:22:11.735278.json [Content-Type=application/json]...
# / [1 files][  4.2 KiB/  4.2 KiB]
# Operation completed over 1 objects/4.2 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_USAHEP_GRU_GSA-MD
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_AUTMUV_DS_NS_NPU_ADLT_WES_2022-03-10T08:22:16.691744.json [Content-Type=application/json]...
# / [1 files][  3.4 KiB/  3.4 KiB]
# Operation completed over 1 objects/3.4 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_AUTMUV_DS_NS_NPU_ADLT_WES
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_CZEMTH_GRU_GSA-MD_2022-03-10T08:22:21.629782.json [Content-Type=application/json]...
# / [1 files][  3.7 KiB/  3.7 KiB]
# Operation completed over 1 objects/3.7 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_CZEMTH_GRU_GSA-MD
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_USAHEP_GRU_WES_2022-03-10T08:22:26.933964.json [Content-Type=application/json]...
# / [1 files][  4.4 KiB/  4.4 KiB]
# Operation completed over 1 objects/4.4 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_USAHEP_GRU_WES
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_MI_UnivUtah_DS_CVD_WES_2022-03-10T08:22:31.910608.json [Content-Type=application/json]...
# / [1 files][  6.4 KiB/  6.4 KiB]
# Operation completed over 1 objects/6.4 KiB.
# AnVIL_CCDG_Broad_MI_UnivUtah_DS_CVD_WES
# 200
# ##########################
# Copying file://./ANVIL_CMG_BROAD_BRAIN_SHERR_WGS_2022-03-10T08:22:37.363127.json [Content-Type=application/json]...
# / [1 files][  3.3 KiB/  3.3 KiB]
# Operation completed over 1 objects/3.3 KiB.
# ANVIL_CMG_BROAD_BRAIN_SHERR_WGS
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Broad_NP_Epilepsy_ITAICB_HMB_NPU_MDS_WES_2022-03-10T08:22:42.380387.json [Content-Type=application/json]...
# / [1 files][  4.6 KiB/  4.6 KiB]
# Operation completed over 1 objects/4.6 KiB.
# AnVIL_CCDG_Broad_NP_Epilepsy_ITAICB_HMB_NPU_MDS_WES
# 200
# ##########################
# Copying file://./anvil_ccdg_broad_ai_ibd_daly_rioux_niddk_gsa_2022-03-10T08:22:47.343465.json [Content-Type=application/json]...
# / [1 files][  4.2 KiB/  4.2 KiB]
# Operation completed over 1 objects/4.2 KiB.
# anvil_ccdg_broad_ai_ibd_daly_rioux_niddk_gsa
# 200
# ##########################
# Copying file://./AnVIL_GTEx_V8_hg38_2022-03-10T08:22:52.277352.json [Content-Type=application/json]...
# / [1 files][  9.2 KiB/  9.2 KiB]
# Operation completed over 1 objects/9.2 KiB.
# AnVIL_GTEx_V8_hg38
# 200
# ##########################
# Copying file://./AnVIL_CCDG_Baylor_CVD_HemStroke_Regards_DS_WGS_2022-03-10T08:22:57.305983.json [Content-Type=application/json]...
# / [1 files][  3.9 KiB/  3.9 KiB]
# Operation completed over 1 objects/3.9 KiB.
# AnVIL_CCDG_Baylor_CVD_HemStroke_Regards_DS_WGS
# 200
